# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitues and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to th cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['karagay',
#  'atyrau',
#  'nikolskoye',
#  'barrow',
#  'mys shmidta',
#  'bluff',
#  'ushuaia',
#  'imeni poliny osipenko',
#  'kaitangata',
#  'sentyabrskiy',
#  'te anau',
#  'nelson bay',
#  'provideniya',
#  'ayan',
#  'tecoanapa',
#  'busselton',
#  'tuktoyaktuk',
#  'longyearbyen',
#  'tuy hoa',
#  'schmallenberg',
#  'mataura',
#  'port alfred',
#  'avarua',
#  'stornoway',
#  'kahului',
#  'victoria',
#  'hermanus',
#  'hilo',
#  'asayita',
#  'rikitea',
#  'east london',
#  'padang',
#  'la ronge',
#  'mahadday weyne',
#  'faanui',
#  'lebu',
#  'broome',
#  'albany',
#  'janakkala',
#  'vila franca do campo',
#  'vestmannaeyjar',
#  'saint-georges',
#  'aklavik',
#  'kapaa',
#  'tapes',
#  'belmonte',
#  'dalbandin',
#  'hirara',
#  'cabo san lucas',
#  'arraial do cabo',
#  'karaul',
#  'san cristobal',
#  'ridgecrest',
#  'damietta',
#  'saint anthony',
#  'stokmarknes',
#  'saldanha',
#  'puerto ayora',
#  'fairbanks',
#  'margate',
#  'sao filipe',
#  'umzimvubu',
#  'port moresby',
#  'ilulissat',
#  'derzhavinsk',
#  'vaini',
#  'upernavik',
#  'hay river',
#  'lompoc',
#  'pervomayskiy',
#  'grand gaube',
#  'bairiki',
#  'normandin',
#  'severo-kurilsk',
#  'vaitupu',
#  'port-gentil',
#  'cape town',
#  'benjamin hill',
#  'taoudenni',
#  'hobart',
#  'leshukonskoye',
#  'labutta',
#  'tamandare',
#  'tumannyy',
#  'ribeira grande',
#  'bonthe',
#  'taolanaro',
#  'bredasdorp',
#  'launceston',
#  'helena',
#  'rio grande',
#  'amderma',
#  'chibombo',
#  'tahta',
#  'ewa beach',
#  'bowen',
#  'portland',
#  'punta arenas',
#  'sabang',
#  'la romana',
#  'eirunepe',
#  'aykhal',
#  'bengkulu',
#  'ancud',
#  'poum',
#  'guarapari',
#  'urdzhar',
#  'chokurdakh',
#  'havre-saint-pierre',
#  'bambous virieux',
#  'yellowknife',
#  'berlevag',
#  'isangel',
#  'moroni',
#  'klaksvik',
#  'chapleau',
#  'lodja',
#  'marietta',
#  'talnakh',
#  'katsuura',
#  'abu samrah',
#  'dudinka',
#  'hasaki',
#  'palu',
#  'salihorsk',
#  'jamestown',
#  'ponta do sol',
#  'hithadhoo',
#  'kissing',
#  'ylojarvi',
#  'cherskiy',
#  'castro',
#  'hella',
#  'lebork',
#  'birjand',
#  'tuatapere',
#  'galway',
#  'peniche',
#  'newcastle',
#  'barentsburg',
#  'mumbwa',
#  'saleaula',
#  'port hardy',
#  'villarrica',
#  'tautira',
#  'sikonge',
#  'nantucket',
#  'georgetown',
#  'marzuq',
#  'weymouth',
#  'play cu',
#  'falealupo',
#  'saskylakh',
#  'zyryanka',
#  'kaniama',
#  'kununurra',
#  'lubango',
#  'qaanaaq',
#  'khonuu',
#  'charagua',
#  'fort nelson',
#  'qaracala',
#  'oksfjord',
#  'henties bay',
#  'makakilo city',
#  'nanakuli',
#  'coquimbo',
#  'dikson',
#  'pueblo nuevo',
#  'sriperumbudur',
#  'chiavari',
#  'jones',
#  'fortuna',
#  'luanda',
#  'pevek',
#  'belushya guba',
#  'torbay',
#  'shitanjing',
#  'ovalle',
#  'grand forks',
#  'illoqqortoormiut',
#  'gamba',
#  'lago da pedra',
#  'mar del plata',
#  'bethel',
#  'nizhneyansk',
#  'cascais',
#  'lorengau',
#  'port elizabeth',
#  'leningradskiy',
#  'asau',
#  'chuy',
#  'tasiilaq',
#  'nouadhibou',
#  'nuevitas',
#  'banmo',
#  'sarapul',
#  'bilma',
#  'kavieng',
#  'mamallapuram',
#  'rabo de peixe',
#  'ardakan',
#  'yatou',
#  'carnarvon',
#  'sorland',
#  'uwayl',
#  'lufilufi',
#  'oga',
#  'pierre',
#  'sulina',
#  'zolotinka',
#  'lieksa',
#  'moiyabana',
#  'catia la mar',
#  'robe',
#  'barkhan',
#  'tessalit',
#  'lasa',
#  'iranshahr',
#  'palaia fokaia',
#  'norman wells',
#  'butaritari',
#  'vardo',
#  'santa barbara',
#  'gravdal',
#  'ahuimanu',
#  'atar',
#  'caravelas',
#  'zhemchuzhnyy',
#  'necochea',
#  'namatanai',
#  'narsaq',
#  'richard toll',
#  'priladozhskiy',
#  'banda aceh',
#  'kushmurun',
#  'jumla',
#  'korla',
#  'lata',
#  'manaure',
#  'menongue',
#  'bonavista',
#  'verkhoyansk',
#  'sturgeon bay',
#  'kodiak',
#  'bafata',
#  'kapiri mposhi',
#  'balimo',
#  'vila velha',
#  'bamiantong',
#  'bima',
#  'terrace',
#  'nanortalik',
#  'thompson',
#  'rawlins',
#  'santarem',
#  'codrington',
#  'altamont',
#  'tiksi',
#  'palana',
#  'atuona',
#  'manado',
#  'tiruchchendur',
#  'high prairie',
#  'areia branca',
#  'cayenne',
#  'waterford',
#  'lagoa',
#  'inzer',
#  'buala',
#  'akyab',
#  'beringovskiy',
#  'landang',
#  'chateaudun',
#  'touros',
#  'mao',
#  'mollendo',
#  'sakakah',
#  'kruisfontein',
#  'carutapera',
#  'esperance',
#  'vidim',
#  'moron',
#  'luderitz',
#  'sistranda',
#  'khatanga',
#  'muzhi',
#  'avera',
#  'najran',
#  'umm kaddadah',
#  'cairns',
#  'labuhan',
#  'eyl',
#  'betong',
#  'belyy yar',
#  'alice springs',
#  'maravilha',
#  'alta floresta',
#  'we',
#  'kaili',
#  'sovetskiy',
#  'ponta delgada',
#  'tahlequah',
#  'lahat',
#  'lumeje',
#  'sechura',
#  'new norfolk',
#  'sonta',
#  'pangody',
#  'tucupita',
#  'at-bashi',
#  'mangan',
#  'gushikawa',
#  'sinnamary',
#  'toliary',
#  'geraldton',
#  'mount gambier',
#  'grand baie',
#  'polyarnyy',
#  'zaysan',
#  'powell river',
#  'husavik',
#  'burkhala',
#  'kieta',
#  'arrifes',
#  'paveh',
#  'nakamura',
#  'aswan',
#  'dzhusaly',
#  'bud',
#  'port augusta',
#  'laguna',
#  'hofn',
#  'santa rosa',
#  'urusha',
#  'umm lajj',
#  'kerki',
#  'westport',
#  'guajara-mirim',
#  'ormoz',
#  'halalo',
#  'inhambane',
#  'grindavik',
#  'bilibino',
#  'road town',
#  'sayyan',
#  'pisco',
#  'chake chake',
#  'paka',
#  'kisangani',
#  'souillac',
#  'shingu',
#  'nara',
#  'ust-kamchatsk',
#  'mukhen',
#  'solano',
#  'ternate',
#  'port lincoln',
#  'derby',
#  'jahrom',
#  'hongan',
#  'deputatskiy',
#  'murgab',
#  'tortoli',
#  'bardiyah',
#  'lampazos de naranjo',
#  'mitsamiouli',
#  'shenjiamen',
#  'eskisehir',
#  'panguna',
#  'saint-philippe',
#  'kautokeino',
#  'bontang',
#  'chaparral',
#  'sao miguel do araguaia',
#  'gorontalo',
#  'inuvik',
#  'tigre',
#  'priupskiy',
#  'morvi',
#  'ajdabiya',
#  'tevaitoa',
#  'salalah',
#  'luganville',
#  'bangui',
#  'bose',
#  'jackson',
#  'marcona',
#  'youghal',
#  'dwarka',
#  'ambilobe',
#  'itabera',
#  'nacimiento',
#  'ormara',
#  'kamenka',
#  'kaputa',
#  'rawson',
#  'thinadhoo',
#  'carauari',
#  'itacare',
#  'townsville',
#  'chivilcoy',
#  'sioux lookout',
#  'quatre cocos',
#  'tromso',
#  'mariental',
#  'cowra',
#  'surgut',
#  'honiara',
#  'lookan',
#  'quipile',
#  'iqaluit',
#  'mlonggo',
#  'south lake tahoe',
#  'codajas',
#  'yichang',
#  'ponferrada',
#  'buraydah',
#  'manzhouli',
#  'warqla',
#  'langenburg',
#  'krasnoarmeysk',
#  'omboue',
#  'katherine',
#  'ust-maya',
#  'yulara',
#  'baymak',
#  'ust-omchug',
#  'ayagoz',
#  'sobolevo',
#  'tabou',
#  'toropets',
#  'pangnirtung',
#  'devaprayag',
#  'houston',
#  'auki',
#  'nome',
#  'grand river south east',
#  'starosubkhangulovo',
#  'muborak',
#  'marsh harbour',
#  'san patricio',
#  'borzya',
#  'haines junction',
#  'cidreira',
#  'adrar',
#  'purranque',
#  'whitianga',
#  'ixtapa',
#  'bitung',
#  'kaseda',
#  'solnechnyy',
#  'karratha',
#  'vao',
#  'terni',
#  'dreux',
#  'coihaique',
#  'nanyamba',
#  'singkang',
#  'olafsvik',
#  'mahebourg',
#  'camana',
#  'copiapo',
#  'bandundu',
#  'beira',
#  'broken hill',
#  'itoman',
#  'campbellsville',
#  'olga',
#  'beruwala',
#  'wanning',
#  'kijang',
#  'huazolotitlan',
#  'mehamn',
#  'gisborne',
#  'cockburn town',
#  'sept-iles',
#  'jinchengjiang',
#  'smithers',
#  'sao joao da barra',
#  'malinalco',
#  'laranjeiras do sul',
#  'anadyr',
#  'college',
#  'melita',
#  'dauphin',
#  'bugiri',
#  'praia da vitoria',
#  'coffs harbour',
#  'wum',
#  'dingle',
#  'duz',
#  'ahipara',
#  'natal',
#  'chacabuco',
#  'guadalupe y calvo',
#  'esmeralda',
#  'hamilton',
#  'aquiraz',
#  'flinders',
#  'atlantic city',
#  'saint george',
#  'iskateley',
#  'havoysund',
#  'huilong',
#  'romny',
#  'port hedland',
#  'palmer',
#  'attawapiskat',
#  'nguiu',
#  'anori',
#  'san javier',
#  'fenoarivo atsinanana',
#  'skagastrond',
#  'kudahuvadhoo',
#  'sumbe',
#  'alexandria',
#  'manta',
#  'severobaykalsk',
#  'hami',
#  'mandalgovi',
#  'juifang',
#  'muromtsevo',
#  'itarema',
#  'luena',
#  'douglas',
#  'buchanan',
#  'vanimo',
#  'monrovia',
#  'san andres',
#  'joetsu',
#  'ammon',
#  'colares',
#  'cornelio procopio',
#  'doctor pedro p. pena',
#  'saint-augustin',
#  'astoria',
#  'eureka',
#  'rancho santa margarita',
#  'chumikan',
#  'nadym',
#  'guiratinga',
#  'senneterre',
#  'acapulco',
#  'camopi',
#  'cedar city',
#  'sola',
#  'cedral',
#  'emilio carranza',
#  'marrakesh',
#  'pyshchug',
#  'oranjemund',
#  'sao raimundo das mangabeiras',
#  'egvekinot',
#  'zhigansk',
#  'puerto del rosario',
#  'jaisalmer',
#  'merauke',
#  'zaozerne',
#  'waipawa',
#  'sayula',
#  'winnemucca',
#  'comodoro rivadavia',
#  'chicama',
#  'elizabeth city',
#  'pombas',
#  'rocha',
#  'pitimbu',
#  'simao',
#  'nizhniy tsasuchey',
#  'sitka',
#  'beloha',
#  'alba',
#  'brattvag',
#  'urucui',
#  'faya',
#  'bograd',
#  'noumea',
#  'cachira',
#  'george',
#  'ondjiva',
#  'fukue',
#  'santa cruz del sur',
#  'airai',
#  'miri',
#  'jacqueville',
#  'manavalakurichi',
#  'samusu',
#  'palabuhanratu',
#  'erenhot',
#  'aripuana',
#  'bandar',
#  'tsihombe',
#  'guerrero negro',
#  'vaasa',
#  'tabiauea',
#  'capao bonito',
#  'sinjar',
#  'half moon bay',
#  'anloga',
#  'axim',
#  'wilmington',
#  'tidore',
#  'saint-pierre',
#  'koslan',
#  'okotoks',
#  'port keats',
#  'mount isa',
#  'hargeysa',
#  'camacupa',
#  'dera bugti',
#  'shestakovo',
#  'ulladulla',
#  'danielskuil',
#  'capaccio',
#  'tingi',
#  'torbat-e jam',
#  'graaff-reinet',
#  'moindou',
#  'xghajra',
#  'suao',
#  'oltina',
#  'biak',
#  'pedernales',
#  'puerto escondido',
#  'hualmay',
#  'bocas del toro',
#  'kotelnich',
#  'kimbe',
#  'tubuala',
#  'abreu e lima',
#  'upington',
#  'den helder',
#  'tabas',
#  'kachikau',
#  'aberdeen',
#  'chibuto',
#  'fruitvale',
#  'aflu',
#  'qasigiannguit',
#  'aksu',
#  'palmares do sul',
#  'lafiagi',
#  'kovdor',
#  'lavrentiya',
#  'champerico',
#  'craig',
#  'ocampo',
#  'dunedin',
#  'kigoma',
#  'meulaboh',
#  'nezhinka',
#  'clyde river',
#  'mendahara',
#  'tinskoy',
#  'rumphi',
#  'chimore',
#  'anaconda',
#  'panjab',
#  'tchaourou',
#  'saint-gaudens',
#  'ozernovskiy',
#  'ketchikan',
#  'trat',
#  'srandakan',
#  'pacific grove',
#  'salvador',
#  'davidson',
#  'cheyur',
#  'mengcheng',
#  'kharp',
#  'konya',
#  'colchester',
#  'pochutla',
#  'luau',
#  'maturin',
#  'kollam',
#  'kupang',
#  'vila',
#  'mandera',
#  'sitio novo do tocantins',
#  'altamira',
#  'okha',
#  'yar-sale',
#  'port macquarie',
#  'opuwo',
#  'la palma',
#  'nemuro',
#  'monte alegre',
#  'piacabucu',
#  'xiangxiang',
#  'anopino',
#  'makarov',
#  'blackwater',
#  'isla vista',
#  'anuradhapura',
#  'pangkalanbuun',
#  'yithion',
#  'agadir',
#  'harlingen',
#  'hambantota',
#  'belaya gora',
#  'nanchang',
#  'sri aman',
#  'corrente',
#  'nanga eboko',
#  'helong',
#  'butembo',
#  'qui nhon',
#  'mahajanga',
#  'tarancon',
#  'nishihara',
#  'saint-jean-de-braye',
#  'poronaysk',
#  'andenes',
#  'fevralsk',
#  'louisbourg',
#  'samarai',
#  'tsiroanomandidy',
#  'russell',
#  'malanje',
#  'griffith',
#  'petropavlovsk-kamchatskiy',
#  'svetlyy',
#  'nizhniy kuranakh',
#  'ipixuna',
#  'antofagasta',
#  'izhma',
#  'pita',
#  'vallenar',
#  'ust-kuyga',
#  'dunda',
#  'ruatoria',
#  'warrington',
#  'changji',
#  'nieuw amsterdam',
#  'strezhevoy',
#  'viligili',
#  'nabire',
#  'abha',
#  'langsa',
#  'jiexiu',
#  'tignere',
#  'paamiut',
#  'maiduguri',
#  'meadow lake',
#  'sassandra',
#  'nayoro',
#  'placerville',
#  'biryusinsk',
#  'virginia beach',
#  'dakar',
#  'kibala',
#  'daxian',
#  'kokkola',
#  'kavaratti',
#  'taki',
#  'oktyabrskoye',
#  'bo phloi',
#  'lewistown',
#  'parrsboro',
#  'ponte de sor',
#  'atocha',
#  'estepona',
#  'katobu',
#  'grand bank',
#  'alofi',
#  'mogadishu',
#  'kasongo-lunda',
#  'wanxian',
#  'kirkwall',
#  'alyangula',
#  'zigong',
#  'banyo',
#  'usakos',
#  'tagabas',
#  'probolinggo',
#  'cortez',
#  'boa vista']

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb60c08a5202eda842c6a14906558944

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb60c08a5202eda842c6a14906558944&q=boa vista

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | karagay
# Processing Record 2 of Set 16 | atyrau
# Processing Record 3 of Set 16 | nikolskoye
# Processing Record 4 of Set 16 | barrow
# Processing Record 5 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 16 | bluff
# Processing Record 7 of Set 16 | ushuaia
# Processing Record 8 of Set 16 | imeni poliny osipenko
# Processing Record 9 of Set 16 | kaitangata
# Processing Record 10 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 16 | te anau
# Processing Record 12 of Set 16 | nelson bay
# Processing Record 13 of Set 16 | provideniya
# Processing Record 14 of Set 16 | ayan
# Processing Record 15 of Set 16 | tecoanapa
# Processing Record 16 of Set 16 | busselton
# Processing Record 17 of Set 16 | tuktoyaktuk
# Processing Record 18 of Set 16 | longyearbyen
# Processing Record 19 of Set 16 | tuy hoa
# Processing Record 20 of Set 16 | schmallenberg
# Processing Record 21 of Set 16 | mataura
# Processing Record 22 of Set 16 | port alfred
# Processing Record 23 of Set 16 | avarua
# Processing Record 24 of Set 16 | stornoway
# Processing Record 25 of Set 16 | kahului
# Processing Record 26 of Set 16 | victoria
# Processing Record 27 of Set 16 | hermanus
# Processing Record 28 of Set 16 | hilo
# Processing Record 29 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 30 of Set 16 | rikitea
# Processing Record 31 of Set 16 | east london
# Processing Record 32 of Set 16 | padang
# Processing Record 33 of Set 16 | la ronge
# Processing Record 34 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 35 of Set 16 | faanui
# Processing Record 36 of Set 16 | lebu
# Processing Record 37 of Set 16 | broome
# Processing Record 38 of Set 16 | albany
# Processing Record 39 of Set 16 | janakkala
# Processing Record 40 of Set 16 | vila franca do campo
# Processing Record 41 of Set 16 | vestmannaeyjar
# Processing Record 42 of Set 16 | saint-georges
# Processing Record 43 of Set 16 | aklavik
# Processing Record 44 of Set 16 | kapaa
# Processing Record 45 of Set 16 | tapes
# Processing Record 46 of Set 16 | belmonte
# Processing Record 47 of Set 16 | dalbandin
# Processing Record 48 of Set 16 | hirara
# Processing Record 49 of Set 16 | cabo san lucas
# Processing Record 50 of Set 16 | arraial do cabo
# Processing Record 1 of Set 17 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 17 | san cristobal
# Processing Record 3 of Set 17 | ridgecrest
# Processing Record 4 of Set 17 | damietta
# Processing Record 5 of Set 17 | saint anthony
# Processing Record 6 of Set 17 | stokmarknes
# Processing Record 7 of Set 17 | saldanha
# Processing Record 8 of Set 17 | puerto ayora
# Processing Record 9 of Set 17 | fairbanks
# Processing Record 10 of Set 17 | margate
# Processing Record 11 of Set 17 | sao filipe
# Processing Record 12 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 17 | port moresby
# Processing Record 14 of Set 17 | ilulissat
# Processing Record 15 of Set 17 | derzhavinsk
# Processing Record 16 of Set 17 | vaini
# Processing Record 17 of Set 17 | upernavik
# Processing Record 18 of Set 17 | hay river
# Processing Record 19 of Set 17 | lompoc
# Processing Record 20 of Set 17 | pervomayskiy
# Processing Record 21 of Set 17 | grand gaube
# Processing Record 22 of Set 17 | bairiki
# Processing Record 23 of Set 17 | normandin
# Processing Record 24 of Set 17 | severo-kurilsk
# Processing Record 25 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 17 | port-gentil
# Processing Record 27 of Set 17 | cape town
# Processing Record 28 of Set 17 | benjamin hill
# Processing Record 29 of Set 17 | taoudenni
# Processing Record 30 of Set 17 | hobart
# Processing Record 31 of Set 17 | leshukonskoye
# Processing Record 32 of Set 17 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 17 | tamandare
# Processing Record 34 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 17 | ribeira grande
# Processing Record 36 of Set 17 | bonthe
# Processing Record 37 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 17 | bredasdorp
# Processing Record 39 of Set 17 | launceston
# Processing Record 40 of Set 17 | helena
# Processing Record 41 of Set 17 | rio grande
# Processing Record 42 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 17 | chibombo
# Processing Record 44 of Set 17 | tahta
# Processing Record 45 of Set 17 | ewa beach
# Processing Record 46 of Set 17 | bowen
# Processing Record 47 of Set 17 | portland
# Processing Record 48 of Set 17 | punta arenas
# Processing Record 49 of Set 17 | sabang
# Processing Record 50 of Set 17 | la romana
# Processing Record 1 of Set 18 | eirunepe
# Processing Record 2 of Set 18 | aykhal
# Processing Record 3 of Set 18 | bengkulu
# Processing Record 4 of Set 18 | ancud
# Processing Record 5 of Set 18 | poum
# Processing Record 6 of Set 18 | guarapari
# Processing Record 7 of Set 18 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 18 | chokurdakh
# Processing Record 9 of Set 18 | havre-saint-pierre
# Processing Record 10 of Set 18 | bambous virieux
# Processing Record 11 of Set 18 | yellowknife
# Processing Record 12 of Set 18 | berlevag
# Processing Record 13 of Set 18 | isangel
# Processing Record 14 of Set 18 | moroni
# Processing Record 15 of Set 18 | klaksvik
# Processing Record 16 of Set 18 | chapleau
# Processing Record 17 of Set 18 | lodja
# Processing Record 18 of Set 18 | marietta
# Processing Record 19 of Set 18 | talnakh
# Processing Record 20 of Set 18 | katsuura
# Processing Record 21 of Set 18 | abu samrah
# Processing Record 22 of Set 18 | dudinka
# Processing Record 23 of Set 18 | hasaki
# Processing Record 24 of Set 18 | palu
# Processing Record 25 of Set 18 | salihorsk
# Processing Record 26 of Set 18 | jamestown
# Processing Record 27 of Set 18 | ponta do sol
# Processing Record 28 of Set 18 | hithadhoo
# Processing Record 29 of Set 18 | kissing
# Processing Record 30 of Set 18 | ylojarvi
# Processing Record 31 of Set 18 | cherskiy
# Processing Record 32 of Set 18 | castro
# Processing Record 33 of Set 18 | hella
# Processing Record 34 of Set 18 | lebork
# Processing Record 35 of Set 18 | birjand
# Processing Record 36 of Set 18 | tuatapere
# Processing Record 37 of Set 18 | galway
# Processing Record 38 of Set 18 | peniche
# Processing Record 39 of Set 18 | newcastle
# Processing Record 40 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 18 | mumbwa
# Processing Record 42 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 18 | port hardy
# Processing Record 44 of Set 18 | villarrica
# Processing Record 45 of Set 18 | tautira
# Processing Record 46 of Set 18 | sikonge
# Processing Record 47 of Set 18 | nantucket
# Processing Record 48 of Set 18 | georgetown
# Processing Record 49 of Set 18 | marzuq
# Processing Record 50 of Set 18 | weymouth
# Processing Record 1 of Set 19 | play cu
# City not found. Skipping...
# Processing Record 2 of Set 19 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 19 | saskylakh
# Processing Record 4 of Set 19 | zyryanka
# Processing Record 5 of Set 19 | kaniama
# Processing Record 6 of Set 19 | kununurra
# Processing Record 7 of Set 19 | lubango
# Processing Record 8 of Set 19 | qaanaaq
# Processing Record 9 of Set 19 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 19 | charagua
# Processing Record 11 of Set 19 | fort nelson
# Processing Record 12 of Set 19 | qaracala
# Processing Record 13 of Set 19 | oksfjord
# Processing Record 14 of Set 19 | henties bay
# Processing Record 15 of Set 19 | makakilo city
# Processing Record 16 of Set 19 | nanakuli
# Processing Record 17 of Set 19 | coquimbo
# Processing Record 18 of Set 19 | dikson
# Processing Record 19 of Set 19 | pueblo nuevo
# Processing Record 20 of Set 19 | sriperumbudur
# Processing Record 21 of Set 19 | chiavari
# Processing Record 22 of Set 19 | jones
# Processing Record 23 of Set 19 | fortuna
# Processing Record 24 of Set 19 | luanda
# Processing Record 25 of Set 19 | pevek
# Processing Record 26 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 19 | torbay
# Processing Record 28 of Set 19 | shitanjing
# Processing Record 29 of Set 19 | ovalle
# Processing Record 30 of Set 19 | grand forks
# Processing Record 31 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 19 | gamba
# Processing Record 33 of Set 19 | lago da pedra
# Processing Record 34 of Set 19 | mar del plata
# Processing Record 35 of Set 19 | bethel
# Processing Record 36 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 19 | cascais
# Processing Record 38 of Set 19 | lorengau
# Processing Record 39 of Set 19 | port elizabeth
# Processing Record 40 of Set 19 | leningradskiy
# Processing Record 41 of Set 19 | asau
# Processing Record 42 of Set 19 | chuy
# Processing Record 43 of Set 19 | tasiilaq
# Processing Record 44 of Set 19 | nouadhibou
# Processing Record 45 of Set 19 | nuevitas
# Processing Record 46 of Set 19 | banmo
# City not found. Skipping...
# Processing Record 47 of Set 19 | sarapul
# Processing Record 48 of Set 19 | bilma
# Processing Record 49 of Set 19 | kavieng
# Processing Record 50 of Set 19 | mamallapuram
# Processing Record 1 of Set 20 | rabo de peixe
# Processing Record 2 of Set 20 | ardakan
# Processing Record 3 of Set 20 | yatou
# Processing Record 4 of Set 20 | carnarvon
# Processing Record 5 of Set 20 | sorland
# Processing Record 6 of Set 20 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 20 | lufilufi
# Processing Record 8 of Set 20 | oga
# Processing Record 9 of Set 20 | pierre
# Processing Record 10 of Set 20 | sulina
# Processing Record 11 of Set 20 | zolotinka
# City not found. Skipping...
# Processing Record 12 of Set 20 | lieksa
# Processing Record 13 of Set 20 | moiyabana
# City not found. Skipping...
# Processing Record 14 of Set 20 | catia la mar
# Processing Record 15 of Set 20 | robe
# Processing Record 16 of Set 20 | barkhan
# Processing Record 17 of Set 20 | tessalit
# Processing Record 18 of Set 20 | lasa
# Processing Record 19 of Set 20 | iranshahr
# Processing Record 20 of Set 20 | palaia fokaia
# Processing Record 21 of Set 20 | norman wells
# Processing Record 22 of Set 20 | butaritari
# Processing Record 23 of Set 20 | vardo
# Processing Record 24 of Set 20 | santa barbara
# Processing Record 25 of Set 20 | gravdal
# Processing Record 26 of Set 20 | ahuimanu
# Processing Record 27 of Set 20 | atar
# Processing Record 28 of Set 20 | caravelas
# Processing Record 29 of Set 20 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 30 of Set 20 | necochea
# Processing Record 31 of Set 20 | namatanai
# Processing Record 32 of Set 20 | narsaq
# Processing Record 33 of Set 20 | richard toll
# City not found. Skipping...
# Processing Record 34 of Set 20 | priladozhskiy
# Processing Record 35 of Set 20 | banda aceh
# Processing Record 36 of Set 20 | kushmurun
# Processing Record 37 of Set 20 | jumla
# Processing Record 38 of Set 20 | korla
# Processing Record 39 of Set 20 | lata
# Processing Record 40 of Set 20 | manaure
# Processing Record 41 of Set 20 | menongue
# Processing Record 42 of Set 20 | bonavista
# Processing Record 43 of Set 20 | verkhoyansk
# Processing Record 44 of Set 20 | sturgeon bay
# Processing Record 45 of Set 20 | kodiak
# Processing Record 46 of Set 20 | bafata
# Processing Record 47 of Set 20 | kapiri mposhi
# Processing Record 48 of Set 20 | balimo
# City not found. Skipping...
# Processing Record 49 of Set 20 | vila velha
# Processing Record 50 of Set 20 | bamiantong
# Processing Record 1 of Set 21 | bima
# Processing Record 2 of Set 21 | terrace
# Processing Record 3 of Set 21 | nanortalik
# Processing Record 4 of Set 21 | thompson
# Processing Record 5 of Set 21 | rawlins
# Processing Record 6 of Set 21 | santarem
# Processing Record 7 of Set 21 | codrington
# Processing Record 8 of Set 21 | altamont
# Processing Record 9 of Set 21 | tiksi
# Processing Record 10 of Set 21 | palana
# Processing Record 11 of Set 21 | atuona
# Processing Record 12 of Set 21 | manado
# Processing Record 13 of Set 21 | tiruchchendur
# Processing Record 14 of Set 21 | high prairie
# Processing Record 15 of Set 21 | areia branca
# Processing Record 16 of Set 21 | cayenne
# Processing Record 17 of Set 21 | waterford
# Processing Record 18 of Set 21 | lagoa
# Processing Record 19 of Set 21 | inzer
# Processing Record 20 of Set 21 | buala
# Processing Record 21 of Set 21 | akyab
# Processing Record 22 of Set 21 | beringovskiy
# Processing Record 23 of Set 21 | landang
# City not found. Skipping...
# Processing Record 24 of Set 21 | chateaudun
# Processing Record 25 of Set 21 | touros
# Processing Record 26 of Set 21 | mao
# Processing Record 27 of Set 21 | mollendo
# Processing Record 28 of Set 21 | sakakah
# Processing Record 29 of Set 21 | kruisfontein
# Processing Record 30 of Set 21 | carutapera
# Processing Record 31 of Set 21 | esperance
# Processing Record 32 of Set 21 | vidim
# Processing Record 33 of Set 21 | moron
# Processing Record 34 of Set 21 | luderitz
# Processing Record 35 of Set 21 | sistranda
# Processing Record 36 of Set 21 | khatanga
# Processing Record 37 of Set 21 | muzhi
# Processing Record 38 of Set 21 | avera
# Processing Record 39 of Set 21 | najran
# Processing Record 40 of Set 21 | umm kaddadah
# Processing Record 41 of Set 21 | cairns
# Processing Record 42 of Set 21 | labuhan
# Processing Record 43 of Set 21 | eyl
# Processing Record 44 of Set 21 | betong
# Processing Record 45 of Set 21 | belyy yar
# Processing Record 46 of Set 21 | alice springs
# Processing Record 47 of Set 21 | maravilha
# Processing Record 48 of Set 21 | alta floresta
# Processing Record 49 of Set 21 | we
# City not found. Skipping...
# Processing Record 50 of Set 21 | kaili
# Processing Record 1 of Set 22 | sovetskiy
# Processing Record 2 of Set 22 | ponta delgada
# Processing Record 3 of Set 22 | tahlequah
# Processing Record 4 of Set 22 | lahat
# Processing Record 5 of Set 22 | lumeje
# Processing Record 6 of Set 22 | sechura
# Processing Record 7 of Set 22 | new norfolk
# Processing Record 8 of Set 22 | sonta
# Processing Record 9 of Set 22 | pangody
# Processing Record 10 of Set 22 | tucupita
# Processing Record 11 of Set 22 | at-bashi
# Processing Record 12 of Set 22 | mangan
# Processing Record 13 of Set 22 | gushikawa
# Processing Record 14 of Set 22 | sinnamary
# Processing Record 15 of Set 22 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 22 | geraldton
# Processing Record 17 of Set 22 | mount gambier
# Processing Record 18 of Set 22 | grand baie
# Processing Record 19 of Set 22 | polyarnyy
# Processing Record 20 of Set 22 | zaysan
# Processing Record 21 of Set 22 | powell river
# Processing Record 22 of Set 22 | husavik
# Processing Record 23 of Set 22 | burkhala
# City not found. Skipping...
# Processing Record 24 of Set 22 | kieta
# Processing Record 25 of Set 22 | arrifes
# Processing Record 26 of Set 22 | paveh
# Processing Record 27 of Set 22 | nakamura
# Processing Record 28 of Set 22 | aswan
# Processing Record 29 of Set 22 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 22 | bud
# Processing Record 31 of Set 22 | port augusta
# Processing Record 32 of Set 22 | laguna
# Processing Record 33 of Set 22 | hofn
# Processing Record 34 of Set 22 | santa rosa
# Processing Record 35 of Set 22 | urusha
# Processing Record 36 of Set 22 | umm lajj
# Processing Record 37 of Set 22 | kerki
# City not found. Skipping...
# Processing Record 38 of Set 22 | westport
# Processing Record 39 of Set 22 | guajara-mirim
# City not found. Skipping...
# Processing Record 40 of Set 22 | ormoz
# Processing Record 41 of Set 22 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 22 | inhambane
# Processing Record 43 of Set 22 | grindavik
# Processing Record 44 of Set 22 | bilibino
# Processing Record 45 of Set 22 | road town
# Processing Record 46 of Set 22 | sayyan
# Processing Record 47 of Set 22 | pisco
# Processing Record 48 of Set 22 | chake chake
# Processing Record 49 of Set 22 | paka
# Processing Record 50 of Set 22 | kisangani
# Processing Record 1 of Set 23 | souillac
# Processing Record 2 of Set 23 | shingu
# Processing Record 3 of Set 23 | nara
# Processing Record 4 of Set 23 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 23 | mukhen
# Processing Record 6 of Set 23 | solano
# Processing Record 7 of Set 23 | ternate
# Processing Record 8 of Set 23 | port lincoln
# Processing Record 9 of Set 23 | derby
# Processing Record 10 of Set 23 | jahrom
# City not found. Skipping...
# Processing Record 11 of Set 23 | hongan
# City not found. Skipping...
# Processing Record 12 of Set 23 | deputatskiy
# Processing Record 13 of Set 23 | murgab
# Processing Record 14 of Set 23 | tortoli
# Processing Record 15 of Set 23 | bardiyah
# Processing Record 16 of Set 23 | lampazos de naranjo
# Processing Record 17 of Set 23 | mitsamiouli
# Processing Record 18 of Set 23 | shenjiamen
# Processing Record 19 of Set 23 | eskisehir
# Processing Record 20 of Set 23 | panguna
# Processing Record 21 of Set 23 | saint-philippe
# Processing Record 22 of Set 23 | kautokeino
# Processing Record 23 of Set 23 | bontang
# Processing Record 24 of Set 23 | chaparral
# Processing Record 25 of Set 23 | sao miguel do araguaia
# Processing Record 26 of Set 23 | gorontalo
# Processing Record 27 of Set 23 | inuvik
# Processing Record 28 of Set 23 | tigre
# Processing Record 29 of Set 23 | priupskiy
# Processing Record 30 of Set 23 | morvi
# Processing Record 31 of Set 23 | ajdabiya
# Processing Record 32 of Set 23 | tevaitoa
# Processing Record 33 of Set 23 | salalah
# Processing Record 34 of Set 23 | luganville
# Processing Record 35 of Set 23 | bangui
# Processing Record 36 of Set 23 | bose
# Processing Record 37 of Set 23 | jackson
# Processing Record 38 of Set 23 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 23 | youghal
# Processing Record 40 of Set 23 | dwarka
# Processing Record 41 of Set 23 | ambilobe
# Processing Record 42 of Set 23 | itabera
# Processing Record 43 of Set 23 | nacimiento
# Processing Record 44 of Set 23 | ormara
# Processing Record 45 of Set 23 | kamenka
# Processing Record 46 of Set 23 | kaputa
# Processing Record 47 of Set 23 | rawson
# Processing Record 48 of Set 23 | thinadhoo
# Processing Record 49 of Set 23 | carauari
# Processing Record 50 of Set 23 | itacare
# Processing Record 1 of Set 24 | townsville
# Processing Record 2 of Set 24 | chivilcoy
# Processing Record 3 of Set 24 | sioux lookout
# Processing Record 4 of Set 24 | quatre cocos
# Processing Record 5 of Set 24 | tromso
# Processing Record 6 of Set 24 | mariental
# Processing Record 7 of Set 24 | cowra
# Processing Record 8 of Set 24 | surgut
# Processing Record 9 of Set 24 | honiara
# Processing Record 10 of Set 24 | lookan
# Processing Record 11 of Set 24 | quipile
# Processing Record 12 of Set 24 | iqaluit
# Processing Record 13 of Set 24 | mlonggo
# Processing Record 14 of Set 24 | south lake tahoe
# Processing Record 15 of Set 24 | codajas
# Processing Record 16 of Set 24 | yichang
# Processing Record 17 of Set 24 | ponferrada
# Processing Record 18 of Set 24 | buraydah
# Processing Record 19 of Set 24 | manzhouli
# Processing Record 20 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 24 | langenburg
# Processing Record 22 of Set 24 | krasnoarmeysk
# Processing Record 23 of Set 24 | omboue
# Processing Record 24 of Set 24 | katherine
# Processing Record 25 of Set 24 | ust-maya
# Processing Record 26 of Set 24 | yulara
# Processing Record 27 of Set 24 | baymak
# Processing Record 28 of Set 24 | ust-omchug
# Processing Record 29 of Set 24 | ayagoz
# Processing Record 30 of Set 24 | sobolevo
# Processing Record 31 of Set 24 | tabou
# Processing Record 32 of Set 24 | toropets
# Processing Record 33 of Set 24 | pangnirtung
# Processing Record 34 of Set 24 | devaprayag
# Processing Record 35 of Set 24 | houston
# Processing Record 36 of Set 24 | auki
# Processing Record 37 of Set 24 | nome
# Processing Record 38 of Set 24 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 24 | starosubkhangulovo
# Processing Record 40 of Set 24 | muborak
# Processing Record 41 of Set 24 | marsh harbour
# Processing Record 42 of Set 24 | san patricio
# Processing Record 43 of Set 24 | borzya
# Processing Record 44 of Set 24 | haines junction
# Processing Record 45 of Set 24 | cidreira
# Processing Record 46 of Set 24 | adrar
# Processing Record 47 of Set 24 | purranque
# Processing Record 48 of Set 24 | whitianga
# Processing Record 49 of Set 24 | ixtapa
# Processing Record 50 of Set 24 | bitung
# Processing Record 1 of Set 25 | kaseda
# Processing Record 2 of Set 25 | solnechnyy
# Processing Record 3 of Set 25 | karratha
# Processing Record 4 of Set 25 | vao
# Processing Record 5 of Set 25 | terni
# Processing Record 6 of Set 25 | dreux
# Processing Record 7 of Set 25 | coihaique
# Processing Record 8 of Set 25 | nanyamba
# Processing Record 9 of Set 25 | singkang
# Processing Record 10 of Set 25 | olafsvik
# Processing Record 11 of Set 25 | mahebourg
# Processing Record 12 of Set 25 | camana
# Processing Record 13 of Set 25 | copiapo
# Processing Record 14 of Set 25 | bandundu
# Processing Record 15 of Set 25 | beira
# Processing Record 16 of Set 25 | broken hill
# Processing Record 17 of Set 25 | itoman
# Processing Record 18 of Set 25 | campbellsville
# Processing Record 19 of Set 25 | olga
# Processing Record 20 of Set 25 | beruwala
# Processing Record 21 of Set 25 | wanning
# Processing Record 22 of Set 25 | kijang
# Processing Record 23 of Set 25 | huazolotitlan
# City not found. Skipping...
# Processing Record 24 of Set 25 | mehamn
# Processing Record 25 of Set 25 | gisborne
# Processing Record 26 of Set 25 | cockburn town
# Processing Record 27 of Set 25 | sept-iles
# Processing Record 28 of Set 25 | jinchengjiang
# City not found. Skipping...
# Processing Record 29 of Set 25 | smithers
# Processing Record 30 of Set 25 | sao joao da barra
# Processing Record 31 of Set 25 | malinalco
# Processing Record 32 of Set 25 | laranjeiras do sul
# Processing Record 33 of Set 25 | anadyr
# Processing Record 34 of Set 25 | college
# Processing Record 35 of Set 25 | melita
# Processing Record 36 of Set 25 | dauphin
# Processing Record 37 of Set 25 | bugiri
# Processing Record 38 of Set 25 | praia da vitoria
# Processing Record 39 of Set 25 | coffs harbour
# Processing Record 40 of Set 25 | wum
# Processing Record 41 of Set 25 | dingle
# Processing Record 42 of Set 25 | duz
# City not found. Skipping...
# Processing Record 43 of Set 25 | ahipara
# Processing Record 44 of Set 25 | natal
# Processing Record 45 of Set 25 | chacabuco
# Processing Record 46 of Set 25 | guadalupe y calvo
# Processing Record 47 of Set 25 | esmeralda
# Processing Record 48 of Set 25 | hamilton
# Processing Record 49 of Set 25 | aquiraz
# Processing Record 50 of Set 25 | flinders
# Processing Record 1 of Set 26 | atlantic city
# Processing Record 2 of Set 26 | saint george
# Processing Record 3 of Set 26 | iskateley
# Processing Record 4 of Set 26 | havoysund
# Processing Record 5 of Set 26 | huilong
# Processing Record 6 of Set 26 | romny
# Processing Record 7 of Set 26 | port hedland
# Processing Record 8 of Set 26 | palmer
# Processing Record 9 of Set 26 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 26 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 26 | anori
# Processing Record 12 of Set 26 | san javier
# Processing Record 13 of Set 26 | fenoarivo atsinanana
# Processing Record 14 of Set 26 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 26 | kudahuvadhoo
# Processing Record 16 of Set 26 | sumbe
# Processing Record 17 of Set 26 | alexandria
# Processing Record 18 of Set 26 | manta
# Processing Record 19 of Set 26 | severobaykalsk
# Processing Record 20 of Set 26 | hami
# Processing Record 21 of Set 26 | mandalgovi
# Processing Record 22 of Set 26 | juifang
# City not found. Skipping...
# Processing Record 23 of Set 26 | muromtsevo
# Processing Record 24 of Set 26 | itarema
# Processing Record 25 of Set 26 | luena
# Processing Record 26 of Set 26 | douglas
# Processing Record 27 of Set 26 | buchanan
# Processing Record 28 of Set 26 | vanimo
# Processing Record 29 of Set 26 | monrovia
# Processing Record 30 of Set 26 | san andres
# Processing Record 31 of Set 26 | joetsu
# Processing Record 32 of Set 26 | ammon
# Processing Record 33 of Set 26 | colares
# Processing Record 34 of Set 26 | cornelio procopio
# Processing Record 35 of Set 26 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 26 | saint-augustin
# Processing Record 37 of Set 26 | astoria
# Processing Record 38 of Set 26 | eureka
# Processing Record 39 of Set 26 | rancho santa margarita
# Processing Record 40 of Set 26 | chumikan
# Processing Record 41 of Set 26 | nadym
# Processing Record 42 of Set 26 | guiratinga
# Processing Record 43 of Set 26 | senneterre
# Processing Record 44 of Set 26 | acapulco
# Processing Record 45 of Set 26 | camopi
# Processing Record 46 of Set 26 | cedar city
# Processing Record 47 of Set 26 | sola
# Processing Record 48 of Set 26 | cedral
# Processing Record 49 of Set 26 | emilio carranza
# Processing Record 50 of Set 26 | marrakesh
# Processing Record 1 of Set 27 | pyshchug
# Processing Record 2 of Set 27 | oranjemund
# Processing Record 3 of Set 27 | sao raimundo das mangabeiras
# Processing Record 4 of Set 27 | egvekinot
# Processing Record 5 of Set 27 | zhigansk
# Processing Record 6 of Set 27 | puerto del rosario
# Processing Record 7 of Set 27 | jaisalmer
# Processing Record 8 of Set 27 | merauke
# Processing Record 9 of Set 27 | zaozerne
# Processing Record 10 of Set 27 | waipawa
# Processing Record 11 of Set 27 | sayula
# Processing Record 12 of Set 27 | winnemucca
# Processing Record 13 of Set 27 | comodoro rivadavia
# Processing Record 14 of Set 27 | chicama
# Processing Record 15 of Set 27 | elizabeth city
# Processing Record 16 of Set 27 | pombas
# Processing Record 17 of Set 27 | rocha
# Processing Record 18 of Set 27 | pitimbu
# Processing Record 19 of Set 27 | simao
# Processing Record 20 of Set 27 | nizhniy tsasuchey
# Processing Record 21 of Set 27 | sitka
# Processing Record 22 of Set 27 | beloha
# Processing Record 23 of Set 27 | alba
# Processing Record 24 of Set 27 | brattvag
# Processing Record 25 of Set 27 | urucui
# Processing Record 26 of Set 27 | faya
# Processing Record 27 of Set 27 | bograd
# Processing Record 28 of Set 27 | noumea
# Processing Record 29 of Set 27 | cachira
# Processing Record 30 of Set 27 | george
# Processing Record 31 of Set 27 | ondjiva
# Processing Record 32 of Set 27 | fukue
# Processing Record 33 of Set 27 | santa cruz del sur
# Processing Record 34 of Set 27 | airai
# Processing Record 35 of Set 27 | miri
# Processing Record 36 of Set 27 | jacqueville
# Processing Record 37 of Set 27 | manavalakurichi
# Processing Record 38 of Set 27 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 27 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 27 | erenhot
# Processing Record 41 of Set 27 | aripuana
# Processing Record 42 of Set 27 | bandar
# Processing Record 43 of Set 27 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 27 | guerrero negro
# Processing Record 45 of Set 27 | vaasa
# Processing Record 46 of Set 27 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 27 | capao bonito
# Processing Record 48 of Set 27 | sinjar
# Processing Record 49 of Set 27 | half moon bay
# Processing Record 50 of Set 27 | anloga
# Processing Record 1 of Set 28 | axim
# Processing Record 2 of Set 28 | wilmington
# Processing Record 3 of Set 28 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 28 | saint-pierre
# Processing Record 5 of Set 28 | koslan
# Processing Record 6 of Set 28 | okotoks
# Processing Record 7 of Set 28 | port keats
# Processing Record 8 of Set 28 | mount isa
# Processing Record 9 of Set 28 | hargeysa
# Processing Record 10 of Set 28 | camacupa
# Processing Record 11 of Set 28 | dera bugti
# Processing Record 12 of Set 28 | shestakovo
# Processing Record 13 of Set 28 | ulladulla
# Processing Record 14 of Set 28 | danielskuil
# Processing Record 15 of Set 28 | capaccio
# Processing Record 16 of Set 28 | tingi
# Processing Record 17 of Set 28 | torbat-e jam
# Processing Record 18 of Set 28 | graaff-reinet
# Processing Record 19 of Set 28 | moindou
# Processing Record 20 of Set 28 | xghajra
# City not found. Skipping...
# Processing Record 21 of Set 28 | suao
# City not found. Skipping...
# Processing Record 22 of Set 28 | oltina
# Processing Record 23 of Set 28 | biak
# Processing Record 24 of Set 28 | pedernales
# Processing Record 25 of Set 28 | puerto escondido
# Processing Record 26 of Set 28 | hualmay
# Processing Record 27 of Set 28 | bocas del toro
# Processing Record 28 of Set 28 | kotelnich
# Processing Record 29 of Set 28 | kimbe
# Processing Record 30 of Set 28 | tubuala
# Processing Record 31 of Set 28 | abreu e lima
# Processing Record 32 of Set 28 | upington
# Processing Record 33 of Set 28 | den helder
# Processing Record 34 of Set 28 | tabas
# Processing Record 35 of Set 28 | kachikau
# City not found. Skipping...
# Processing Record 36 of Set 28 | aberdeen
# Processing Record 37 of Set 28 | chibuto
# Processing Record 38 of Set 28 | fruitvale
# Processing Record 39 of Set 28 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 28 | qasigiannguit
# Processing Record 41 of Set 28 | aksu
# Processing Record 42 of Set 28 | palmares do sul
# Processing Record 43 of Set 28 | lafiagi
# Processing Record 44 of Set 28 | kovdor
# Processing Record 45 of Set 28 | lavrentiya
# Processing Record 46 of Set 28 | champerico
# Processing Record 47 of Set 28 | craig
# Processing Record 48 of Set 28 | ocampo
# Processing Record 49 of Set 28 | dunedin
# Processing Record 50 of Set 28 | kigoma
# Processing Record 1 of Set 29 | meulaboh
# Processing Record 2 of Set 29 | nezhinka
# Processing Record 3 of Set 29 | clyde river
# Processing Record 4 of Set 29 | mendahara
# City not found. Skipping...
# Processing Record 5 of Set 29 | tinskoy
# Processing Record 6 of Set 29 | rumphi
# Processing Record 7 of Set 29 | chimore
# Processing Record 8 of Set 29 | anaconda
# Processing Record 9 of Set 29 | panjab
# Processing Record 10 of Set 29 | tchaourou
# Processing Record 11 of Set 29 | saint-gaudens
# Processing Record 12 of Set 29 | ozernovskiy
# Processing Record 13 of Set 29 | ketchikan
# Processing Record 14 of Set 29 | trat
# Processing Record 15 of Set 29 | srandakan
# Processing Record 16 of Set 29 | pacific grove
# Processing Record 17 of Set 29 | salvador
# Processing Record 18 of Set 29 | davidson
# Processing Record 19 of Set 29 | cheyur
# City not found. Skipping...
# Processing Record 20 of Set 29 | mengcheng
# Processing Record 21 of Set 29 | kharp
# Processing Record 22 of Set 29 | konya
# Processing Record 23 of Set 29 | colchester
# Processing Record 24 of Set 29 | pochutla
# Processing Record 25 of Set 29 | luau
# Processing Record 26 of Set 29 | maturin
# Processing Record 27 of Set 29 | kollam
# Processing Record 28 of Set 29 | kupang
# Processing Record 29 of Set 29 | vila
# Processing Record 30 of Set 29 | mandera
# Processing Record 31 of Set 29 | sitio novo do tocantins
# Processing Record 32 of Set 29 | altamira
# Processing Record 33 of Set 29 | okha
# Processing Record 34 of Set 29 | yar-sale
# Processing Record 35 of Set 29 | port macquarie
# Processing Record 36 of Set 29 | opuwo
# Processing Record 37 of Set 29 | la palma
# Processing Record 38 of Set 29 | nemuro
# Processing Record 39 of Set 29 | monte alegre
# Processing Record 40 of Set 29 | piacabucu
# Processing Record 41 of Set 29 | xiangxiang
# Processing Record 42 of Set 29 | anopino
# Processing Record 43 of Set 29 | makarov
# Processing Record 44 of Set 29 | blackwater
# Processing Record 45 of Set 29 | isla vista
# Processing Record 46 of Set 29 | anuradhapura
# Processing Record 47 of Set 29 | pangkalanbuun
# Processing Record 48 of Set 29 | yithion
# City not found. Skipping...
# Processing Record 49 of Set 29 | agadir
# Processing Record 50 of Set 29 | harlingen
# Processing Record 1 of Set 30 | hambantota
# Processing Record 2 of Set 30 | belaya gora
# Processing Record 3 of Set 30 | nanchang
# Processing Record 4 of Set 30 | sri aman
# Processing Record 5 of Set 30 | corrente
# Processing Record 6 of Set 30 | nanga eboko
# Processing Record 7 of Set 30 | helong
# Processing Record 8 of Set 30 | butembo
# Processing Record 9 of Set 30 | qui nhon
# Processing Record 10 of Set 30 | mahajanga
# Processing Record 11 of Set 30 | tarancon
# Processing Record 12 of Set 30 | nishihara
# Processing Record 13 of Set 30 | saint-jean-de-braye
# Processing Record 14 of Set 30 | poronaysk
# Processing Record 15 of Set 30 | andenes
# Processing Record 16 of Set 30 | fevralsk
# City not found. Skipping...
# Processing Record 17 of Set 30 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 30 | samarai
# Processing Record 19 of Set 30 | tsiroanomandidy
# Processing Record 20 of Set 30 | russell
# Processing Record 21 of Set 30 | malanje
# Processing Record 22 of Set 30 | griffith
# Processing Record 23 of Set 30 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 30 | svetlyy
# Processing Record 25 of Set 30 | nizhniy kuranakh
# Processing Record 26 of Set 30 | ipixuna
# Processing Record 27 of Set 30 | antofagasta
# Processing Record 28 of Set 30 | izhma
# Processing Record 29 of Set 30 | pita
# Processing Record 30 of Set 30 | vallenar
# Processing Record 31 of Set 30 | ust-kuyga
# Processing Record 32 of Set 30 | dunda
# Processing Record 33 of Set 30 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 30 | warrington
# Processing Record 35 of Set 30 | changji
# Processing Record 36 of Set 30 | nieuw amsterdam
# Processing Record 37 of Set 30 | strezhevoy
# Processing Record 38 of Set 30 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 30 | nabire
# Processing Record 40 of Set 30 | abha
# Processing Record 41 of Set 30 | langsa
# Processing Record 42 of Set 30 | jiexiu
# Processing Record 43 of Set 30 | tignere
# Processing Record 44 of Set 30 | paamiut
# Processing Record 45 of Set 30 | maiduguri
# Processing Record 46 of Set 30 | meadow lake
# Processing Record 47 of Set 30 | sassandra
# Processing Record 48 of Set 30 | nayoro
# Processing Record 49 of Set 30 | placerville
# Processing Record 50 of Set 30 | biryusinsk
# Processing Record 1 of Set 31 | virginia beach
# Processing Record 2 of Set 31 | dakar
# Processing Record 3 of Set 31 | kibala
# Processing Record 4 of Set 31 | daxian
# City not found. Skipping...
# Processing Record 5 of Set 31 | kokkola
# Processing Record 6 of Set 31 | kavaratti
# Processing Record 7 of Set 31 | taki
# Processing Record 8 of Set 31 | oktyabrskoye
# Processing Record 9 of Set 31 | bo phloi
# Processing Record 10 of Set 31 | lewistown
# Processing Record 11 of Set 31 | parrsboro
# Processing Record 12 of Set 31 | ponte de sor
# Processing Record 13 of Set 31 | atocha
# Processing Record 14 of Set 31 | estepona
# Processing Record 15 of Set 31 | katobu
# Processing Record 16 of Set 31 | grand bank
# Processing Record 17 of Set 31 | alofi
# Processing Record 18 of Set 31 | mogadishu
# Processing Record 19 of Set 31 | kasongo-lunda
# Processing Record 20 of Set 31 | wanxian
# Processing Record 21 of Set 31 | kirkwall
# Processing Record 22 of Set 31 | alyangula
# Processing Record 23 of Set 31 | zigong
# Processing Record 24 of Set 31 | banyo
# Processing Record 25 of Set 31 | usakos
# Processing Record 26 of Set 31 | tagabas
# City not found. Skipping...
# Processing Record 27 of Set 31 | probolinggo
# Processing Record 28 of Set 31 | cortez
# Processing Record 29 of Set 31 | boa vista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
# Convert the array of dictionaires to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng Current Description  Max Temp  \
# 0                Karagay  58.2667   54.9368     overcast clouds     25.48
# 1                 Atyrau  47.1167   51.8833                mist     32.00
# 2             Nikolskoye  59.7035   30.7861     overcast clouds     24.80
# 3                 Barrow  71.2906 -156.7887     overcast clouds    -18.40
# 4                  Bluff -46.6000  168.3333       broken clouds     57.36
# 5                Ushuaia -54.8000  -68.3000       broken clouds     55.40
# 6  Imeni Poliny Osipenko  52.4201  136.4853       broken clouds    -26.81
# 7             Kaitangata -46.2817  169.8464     overcast clouds     55.63
# 8                Te Anau -45.4167  167.7167     overcast clouds     55.04
# 9             Nelson Bay -32.7167  152.1500       broken clouds     70.00
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        94         100       13.47      RU
# 1       100          90        4.47      KZ
# 2        86          90        8.95      RU
# 3        69          90        8.05      US
# 4        78          56        5.37      NZ
# 5        58          75        2.30      AR
# 6        86          69        4.59      RU
# 7        83         100        1.79      NZ
# 8        79         100        0.83      NZ
# 9       100          75        4.61      AU

# %%
# reorder the columnes
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Karagay      RU  58.2667   54.9368     25.48        94
# 1                 Atyrau      KZ  47.1167   51.8833     32.00       100
# 2             Nikolskoye      RU  59.7035   30.7861     24.80        86
# 3                 Barrow      US  71.2906 -156.7887    -18.40        69
# 4                  Bluff      NZ -46.6000  168.3333     57.36        78
# 5                Ushuaia      AR -54.8000  -68.3000     55.40        58
# 6  Imeni Poliny Osipenko      RU  52.4201  136.4853    -26.81        86
# 7             Kaitangata      NZ -46.2817  169.8464     55.63        83
# 8                Te Anau      NZ -45.4167  167.7167     55.04        79
# 9             Nelson Bay      AU -32.7167  152.1500     70.00       100
#
#    Cloudiness  Wind Speed Current Description
# 0         100       13.47     overcast clouds
# 1          90        4.47                mist
# 2          90        8.95     overcast clouds
# 3          90        8.05     overcast clouds
# 4          56        5.37       broken clouds
# 5          75        2.30       broken clouds
# 6          69        4.59       broken clouds
# 7         100        1.79     overcast clouds
# 8         100        0.83     overcast clouds
# 9          75        4.61       broken clouds

# %%
# Create the output files (CSV)
output_data_file = "Weather_Database/Weather_Database.csv"

# Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
