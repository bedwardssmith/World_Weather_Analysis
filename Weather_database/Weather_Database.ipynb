# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitues and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to th cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['sao joao da barra',
#  'champerico',
#  'albany',
#  'sorvag',
#  'hendijan',
#  'hobart',
#  'aykhal',
#  'mataura',
#  'canyon lake',
#  'lokoja',
#  'road town',
#  'nikolskoye',
#  'souillac',
#  'cape town',
#  'new norfolk',
#  'ushuaia',
#  'florianopolis',
#  'luderitz',
#  'avarua',
#  'alpinopolis',
#  'dakar',
#  'cherskiy',
#  'qaanaaq',
#  'tuktoyaktuk',
#  'kruisfontein',
#  'guerrero negro',
#  'hithadhoo',
#  'veracruz',
#  'iqaluit',
#  'arraial do cabo',
#  'taolanaro',
#  'rikitea',
#  'dzaoudzi',
#  'noyabrsk',
#  'vaini',
#  'husavik',
#  'port elizabeth',
#  'nizwa',
#  'saint-francois',
#  'fortuna',
#  'artyom',
#  'ginir',
#  'busselton',
#  'nara',
#  'peace river',
#  'sechura',
#  'port lincoln',
#  'talnakh',
#  'butaritari',
#  'lorengau',
#  'bharatpur',
#  'haines junction',
#  'caohai',
#  'lolua',
#  'punta arenas',
#  'thompson',
#  'kuche',
#  'castro',
#  'tura',
#  'san jeronimo',
#  'nanortalik',
#  'faanui',
#  'kamaishi',
#  'krasnoselkup',
#  'barrow',
#  'beringovskiy',
#  'mullaitivu',
#  'franca',
#  'san ignacio',
#  'bluff',
#  'yarim',
#  'hermanus',
#  'hasaki',
#  'amderma',
#  'tiksi',
#  'aksarka',
#  'hualmay',
#  'utiroa',
#  'victoria',
#  'itarema',
#  'katastarion',
#  'coleraine',
#  'yellowknife',
#  'nizhneyansk',
#  'bonavista',
#  'de-kastri',
#  'ranong',
#  'chuy',
#  'byron bay',
#  'toliary',
#  'aranjuez',
#  'port alfred',
#  'lebu',
#  'roma',
#  'sitka',
#  'dalby',
#  'mar del plata',
#  'upernavik',
#  'sao filipe',
#  'srednekolymsk',
#  'batagay',
#  'sol-iletsk',
#  'yangshe',
#  'port hardy',
#  'buritis',
#  'georgetown',
#  'mahanje',
#  'leningradskiy',
#  'riacho de santana',
#  'ixtapa',
#  'puerto ayora',
#  'hokitika',
#  'grindavik',
#  'maralal',
#  'parry sound',
#  'rubiataba',
#  'banjar',
#  'kapaa',
#  'bukama',
#  'louis trichardt',
#  'christchurch',
#  'poso',
#  'east london',
#  'guarapari',
#  'mys shmidta',
#  'tongren',
#  'avera',
#  'beloha',
#  'san patricio',
#  'cabedelo',
#  'rio gallegos',
#  'severo-kurilsk',
#  'berberati',
#  'borogontsy',
#  'bengkulu',
#  'khatanga',
#  'lososina',
#  'oksfjord',
#  'saint george',
#  'touros',
#  'san cristobal',
#  'sungaipenuh',
#  'dafeng',
#  'bambous virieux',
#  'yulara',
#  'labuan',
#  'sanpetrul-mare',
#  'jatai',
#  'kahului',
#  'saint-philippe',
#  'tawkar',
#  'hilo',
#  'tsihombe',
#  'newark',
#  'penarroya-pueblonuevo',
#  'opuwo',
#  'auki',
#  'amot',
#  'petropavlovsk-kamchatskiy',
#  'altamira',
#  'bhan',
#  'kambove',
#  'dillon',
#  'senador jose porfirio',
#  'lavrentiya',
#  'hofn',
#  'soe',
#  'atuona',
#  'saldanha',
#  'paamiut',
#  'laguna',
#  'kastrakion',
#  'hambantota',
#  'puurmani',
#  'waipawa',
#  'belaya gora',
#  'dawson creek',
#  'novovarshavka',
#  'alugan',
#  'eydhafushi',
#  'golspie',
#  'bundaberg',
#  'khasan',
#  'ambon',
#  'damghan',
#  'peshkopi',
#  'dhidhdhoo',
#  'surazh',
#  'kaputa',
#  'dikson',
#  'belushya guba',
#  'flinders',
#  'thinadhoo',
#  'hue',
#  'mildura',
#  'nagornskiy',
#  'bredasdorp',
#  'blagoyevo',
#  'xichang',
#  'shchelyayur',
#  'palabuhanratu',
#  'garowe',
#  'zhigansk',
#  'ostrovnoy',
#  'wadhwan',
#  'raga',
#  'krikellos',
#  'ukiah',
#  'belmonte',
#  'esperance',
#  'sur',
#  'belokurikha',
#  'batticaloa',
#  'phalodi',
#  'ambilobe',
#  'jinchengjiang',
#  'marawi',
#  'kerki',
#  'tepetzintla',
#  'richards bay',
#  'bar bigha',
#  'pevek',
#  'girvan',
#  'nuuk',
#  'northam',
#  'kanye',
#  'koboko',
#  'leshukonskoye',
#  'nikolayevka',
#  'walvis bay',
#  'alofi',
#  'kavieng',
#  'kaitangata',
#  'mahibadhoo',
#  'ribeira grande',
#  'ulaangom',
#  'tonekabon',
#  'tasiilaq',
#  'guasdualito',
#  'juifang',
#  'faya',
#  'attawapiskat',
#  'mahanoro',
#  'riyadh',
#  'cayenne',
#  'popondetta',
#  'provideniya',
#  'abu samrah',
#  'fairbanks',
#  'maniitsoq',
#  'quixeramobim',
#  'constitucion',
#  'pisco',
#  'sorland',
#  'mega',
#  'kamenka',
#  'sulangan',
#  'norman wells',
#  'bandarbeyla',
#  'pangnirtung',
#  'barentsburg',
#  'kayerkan',
#  'beziers',
#  'komsomolskiy',
#  'ler',
#  'lata',
#  'rorvik',
#  'colares',
#  'kasongo-lunda',
#  'vardo',
#  'wuwei',
#  'airai',
#  'clyde river',
#  'te anau',
#  'ampanihy',
#  'tezu',
#  'mecca',
#  'pontianak',
#  'tucumcari',
#  'ketchikan',
#  'les cayes',
#  'itaporanga',
#  'sukumo',
#  'marfino',
#  'itatiba',
#  'torbay',
#  'wahran',
#  'muros',
#  'olafsvik',
#  'uusikaupunki',
#  'tawnat',
#  'ulagan',
#  'linhares',
#  'mae ramat',
#  'mahebourg',
#  'warri',
#  'carnarvon',
#  'namibe',
#  'hamilton',
#  'vestmannaeyjar',
#  'san andres',
#  'paslek',
#  'lakatoro',
#  'jamestown',
#  'paracuru',
#  'salalah',
#  'akonolinga',
#  'morondava',
#  'galgani',
#  'plettenberg bay',
#  'nyurba',
#  'lagos',
#  'wylie',
#  'labuhan',
#  'bangolo',
#  'newburn',
#  'andilamena',
#  'caravelas',
#  'ballina',
#  'mount gambier',
#  'pietarsaari',
#  'tiznit',
#  'orthez',
#  'porto walter',
#  'bud',
#  'chokurdakh',
#  'bacuit',
#  'chongwe',
#  'warrnambool',
#  'puro',
#  'illoqqortoormiut',
#  'pangai',
#  'coquimbo',
#  'yoichi',
#  'nguiu',
#  'codrington',
#  'anadyr',
#  'passo de camaragibe',
#  'totness',
#  'lodwar',
#  'wloszczowa',
#  'tamandare',
#  'saleaula',
#  'basco',
#  'mendi',
#  'mabaruma',
#  'halifax',
#  'biak',
#  'anchorage',
#  'zuwarah',
#  'urussu',
#  'sysert',
#  'bethel',
#  'bilma',
#  'okha',
#  'yeppoon',
#  'iskateley',
#  'coueron',
#  'jalu',
#  'tumannyy',
#  'valleyview',
#  'cidreira',
#  'ayolas',
#  'maragogi',
#  'lagoa',
#  'anloga',
#  'comodoro rivadavia',
#  'muswellbrook',
#  'ponta do sol',
#  'hervey bay',
#  'ilulissat',
#  'la paz',
#  'bilibino',
#  'ancud',
#  'los llanos de aridane',
#  'neiafu',
#  'karamay',
#  'henties bay',
#  'maicao',
#  'san joaquin',
#  'slupsk',
#  'mushie',
#  'turukhansk',
#  'dien bien',
#  'udachnyy',
#  'vanimo',
#  'mount isa',
#  'narsaq',
#  'gayeri',
#  'jaboatao',
#  'coihaique',
#  'saint-pierre',
#  'gat',
#  'jardim',
#  'nemea',
#  'umea',
#  'hailin',
#  'oranjestad',
#  'puri',
#  'caconda',
#  'grand river south east',
#  'dingle',
#  'valparaiso',
#  'belawan',
#  'rawson',
#  'kodiak',
#  'ye',
#  'puerto madryn',
#  'kushima',
#  'chabahar',
#  'pacific grove',
#  'arlit',
#  'ulaanbaatar',
#  'campbell river',
#  'prince rupert',
#  'upata',
#  'kailua',
#  'marsaxlokk',
#  'kilmez',
#  'deniliquin',
#  'ojinaga',
#  'viligili',
#  'bad aussee',
#  'loukhi',
#  'whitianga',
#  'jamame',
#  'sentyabrskiy',
#  'labutta',
#  'verkhnyaya maksakovka',
#  'celestun',
#  'port blair',
#  'aklavik',
#  'novobirilyussy',
#  'cabo san lucas',
#  'maumere',
#  'geraldton',
#  'mana',
#  'kimbe',
#  'kirakira',
#  'ano mera',
#  'louisbourg',
#  'koumac',
#  'nioro',
#  'mandapam',
#  'devils lake',
#  'saint-augustin',
#  'yar-sale',
#  'burnie',
#  'ahipara',
#  'bend',
#  'chicama',
#  'bargal',
#  'mastic beach',
#  'aksu',
#  'lethem',
#  'axim',
#  'satitoa',
#  'alyangula',
#  'savonlinna',
#  'tucuman',
#  'half moon bay',
#  'kazalinsk',
#  'tamiahua',
#  'razole',
#  'poum',
#  'san quintin',
#  'kostomuksha',
#  'aswan',
#  'umzimvubu',
#  'khonuu',
#  'xunchang',
#  'bam',
#  'san ramon',
#  'skibbereen',
#  'takoradi',
#  'kleck',
#  'tomatlan',
#  'padang',
#  'bambanglipuro',
#  'aberystwyth',
#  'crab hill',
#  'kibala',
#  'vila velha',
#  'severnoye',
#  'carutapera',
#  'vaitupu',
#  'santo domingo',
#  'bathsheba',
#  'tarauaca',
#  'huarmey',
#  'gorom-gorom',
#  'tete',
#  'nha trang',
#  'elizabeth city',
#  'kisanga',
#  'oxapampa',
#  'estacion coahuila',
#  'terra boa',
#  'bairiki',
#  'mayskiy',
#  'xiamen',
#  'beyneu',
#  'mongoumba',
#  'saskylakh',
#  'homer',
#  'nalut',
#  'adrar',
#  'san policarpo',
#  'iberia',
#  'sagua la grande',
#  'victoria falls',
#  'tulum',
#  'gamboma',
#  'pareora',
#  'saryshagan',
#  'lexington park',
#  'lannion',
#  'buin',
#  'rungata',
#  'prince george',
#  'puerto escondido',
#  'samusu',
#  'tagab',
#  'longyearbyen',
#  'guaymas',
#  'urdzhar',
#  'channel-port aux basques',
#  'hami',
#  'saint-joseph',
#  'igurubi',
#  'lalomanu',
#  'wilmington',
#  'kamina',
#  'mackay',
#  'oistins',
#  'yakima',
#  'one hundred mile house',
#  'calvia',
#  'grand centre',
#  'umm lajj',
#  'kharp',
#  'preobrazheniye',
#  'tibiri',
#  'awbari',
#  'varna',
#  'gornyak',
#  'el alto',
#  'abha',
#  'vrede',
#  'doume',
#  'ahuimanu',
#  'liepaja',
#  'abbeville',
#  'chateaudun',
#  'sagar',
#  'oeiras do para',
#  'severnyy',
#  'kapuskasing',
#  'charters towers',
#  'yumaguzino',
#  'saint anthony',
#  'westport',
#  'chikoy',
#  'miyako',
#  'bereznik',
#  'kalemie',
#  'pimentel',
#  'kyaukse',
#  'deputatskiy',
#  'mangai',
#  'zhangye',
#  'mount pleasant',
#  'mikkeli',
#  'uige',
#  'taksimo',
#  'iwanai',
#  'ksenyevka',
#  'berlevag',
#  'inhambane',
#  'iquique',
#  'vila franca do campo',
#  'pirapora do bom jesus',
#  'wagar',
#  'nome',
#  'ati',
#  'taltal',
#  'lompoc',
#  'monduli',
#  'havoysund',
#  'san clemente',
#  'krompachy',
#  'soledade',
#  'groton',
#  'muscatine',
#  'inongo',
#  'baghdad',
#  'sorong',
#  'broome',
#  'barsovo',
#  'acari',
#  'teguldet',
#  'arrecife',
#  'verkhovazhye',
#  'lasa',
#  'rabo de peixe',
#  'muli',
#  'maple creek',
#  'chalchihuites',
#  'skiros',
#  'promissao',
#  'karaul',
#  'saryozek',
#  'grand-bourg',
#  'nautla',
#  'babanusah',
#  'fenoarivo atsinanana',
#  'karratha',
#  'strezhevoy',
#  'inderborskiy',
#  'santa barbara',
#  'sovetskaya gavan',
#  'sola',
#  'morro bay',
#  'vaslui',
#  'margate',
#  'mareeba',
#  'bom jesus',
#  'nyrob',
#  'talcahuano',
#  'jega',
#  'soller',
#  'perbaungan',
#  'tuatapere',
#  'hrebinka',
#  'taoudenni',
#  'bubaque',
#  'bontang',
#  'fukue',
#  'boueni',
#  'alta floresta',
#  'junagarh',
#  'acapulco',
#  'whitehorse',
#  'mitha tiwana',
#  'chapais',
#  'dunedin',
#  'nemuro',
#  'tshela',
#  'surgut',
#  'pecos',
#  'naze',
#  'bardiyah',
#  'mehamn',
#  'sambava',
#  'pedernales',
#  'eureka',
#  'catia la mar',
#  'san jose',
#  'omboue',
#  'talant',
#  'jiuquan',
#  'katiola',
#  'thatcham',
#  'afgoye',
#  'port macquarie',
#  'biloela',
#  'itaituba',
#  'namatanai',
#  'mayo',
#  'fernie',
#  'bolungarvik',
#  'puerto colombia',
#  'chake chake',
#  'kargala',
#  'dhekiajuli',
#  'malakal',
#  'artigas',
#  'solok',
#  'general pico',
#  'lodja',
#  'goure',
#  'portland',
#  'svay rieng',
#  'yumen',
#  'qasigiannguit',
#  'puerto carreno',
#  'balakhninskiy',
#  'shihezi',
#  'linqing',
#  'havre-saint-pierre',
#  'baherden',
#  'kirovskiy',
#  'visby',
#  'gobabis',
#  'shakawe',
#  'spring valley',
#  'diamantina',
#  'tasbuget',
#  'rocha',
#  'sept-iles',
#  'rimouski',
#  'shimoda',
#  'coihueco',
#  'veenendaal',
#  'verkhoshizhemye',
#  'pithoro',
#  'mazamari',
#  'atherton',
#  'ljungby',
#  'veraval',
#  'isangel',
#  'leh',
#  'bermeo',
#  'mogadishu',
#  'santiago del estero',
#  'maldonado',
#  'sistranda',
#  'pingliang',
#  'kerema',
#  'santa fe',
#  'kuching',
#  'loandjili',
#  'corinto',
#  'yingzhong',
#  'lashma',
#  'marzuq',
#  'u thong',
#  'qingdao',
#  'kenai',
#  'las piedras',
#  'singida',
#  'alice springs',
#  'sao paulo de olivenca',
#  'rapid valley',
#  'kudahuvadhoo',
#  'cheuskiny',
#  'hovd',
#  'wawa',
#  'tahta',
#  'quatre cocos',
#  'bondo',
#  'price',
#  'mariental',
#  'samarai',
#  'ipixuna',
#  'tsimlyansk',
#  'susehri',
#  'villa bruzual',
#  'meulaboh',
#  'miles city',
#  'ilhabela',
#  'tena',
#  'kavaratti',
#  'shenkursk',
#  'yelizovo',
#  'ocos']

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb60c08a5202eda842c6a14906558944

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sao joao da barra
# Processing Record 2 of Set 1 | champerico
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 1 | hendijan
# City not found. Skipping...
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | aykhal
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | canyon lake
# Processing Record 10 of Set 1 | lokoja
# Processing Record 11 of Set 1 | road town
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | souillac
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | florianopolis
# Processing Record 18 of Set 1 | luderitz
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | alpinopolis
# Processing Record 21 of Set 1 | dakar
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | guerrero negro
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | veracruz
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | dzaoudzi
# Processing Record 34 of Set 1 | noyabrsk
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | husavik
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | nizwa
# Processing Record 39 of Set 1 | saint-francois
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | artyom
# Processing Record 42 of Set 1 | ginir
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | nara
# Processing Record 45 of Set 1 | peace river
# Processing Record 46 of Set 1 | sechura
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | lorengau
# Processing Record 1 of Set 2 | bharatpur
# Processing Record 2 of Set 2 | haines junction
# Processing Record 3 of Set 2 | caohai
# Processing Record 4 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | tura
# Processing Record 10 of Set 2 | san jeronimo
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | kamaishi
# Processing Record 14 of Set 2 | krasnoselkup
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | beringovskiy
# Processing Record 17 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 2 | franca
# Processing Record 19 of Set 2 | san ignacio
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | yarim
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | aksarka
# Processing Record 27 of Set 2 | hualmay
# Processing Record 28 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | itarema
# Processing Record 31 of Set 2 | katastarion
# Processing Record 32 of Set 2 | coleraine
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | bonavista
# Processing Record 36 of Set 2 | de-kastri
# Processing Record 37 of Set 2 | ranong
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | byron bay
# Processing Record 40 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 2 | aranjuez
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | roma
# Processing Record 45 of Set 2 | sitka
# Processing Record 46 of Set 2 | dalby
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | srednekolymsk
# Processing Record 1 of Set 3 | batagay
# Processing Record 2 of Set 3 | sol-iletsk
# Processing Record 3 of Set 3 | yangshe
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | buritis
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | mahanje
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | riacho de santana
# Processing Record 10 of Set 3 | ixtapa
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | hokitika
# Processing Record 13 of Set 3 | grindavik
# Processing Record 14 of Set 3 | maralal
# Processing Record 15 of Set 3 | parry sound
# Processing Record 16 of Set 3 | rubiataba
# Processing Record 17 of Set 3 | banjar
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | bukama
# Processing Record 20 of Set 3 | louis trichardt
# Processing Record 21 of Set 3 | christchurch
# Processing Record 22 of Set 3 | poso
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | guarapari
# Processing Record 25 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 3 | tongren
# Processing Record 27 of Set 3 | avera
# Processing Record 28 of Set 3 | beloha
# Processing Record 29 of Set 3 | san patricio
# Processing Record 30 of Set 3 | cabedelo
# Processing Record 31 of Set 3 | rio gallegos
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | berberati
# Processing Record 34 of Set 3 | borogontsy
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | lososina
# Processing Record 38 of Set 3 | oksfjord
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | touros
# Processing Record 41 of Set 3 | san cristobal
# Processing Record 42 of Set 3 | sungaipenuh
# Processing Record 43 of Set 3 | dafeng
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | yulara
# Processing Record 46 of Set 3 | labuan
# Processing Record 47 of Set 3 | sanpetrul-mare
# City not found. Skipping...
# Processing Record 48 of Set 3 | jatai
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 4 | hilo
# Processing Record 3 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 4 | newark
# Processing Record 5 of Set 4 | penarroya-pueblonuevo
# Processing Record 6 of Set 4 | opuwo
# Processing Record 7 of Set 4 | auki
# Processing Record 8 of Set 4 | amot
# Processing Record 9 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 4 | altamira
# Processing Record 11 of Set 4 | bhan
# Processing Record 12 of Set 4 | kambove
# Processing Record 13 of Set 4 | dillon
# Processing Record 14 of Set 4 | senador jose porfirio
# Processing Record 15 of Set 4 | lavrentiya
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | soe
# Processing Record 18 of Set 4 | atuona
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | paamiut
# Processing Record 21 of Set 4 | laguna
# Processing Record 22 of Set 4 | kastrakion
# Processing Record 23 of Set 4 | hambantota
# Processing Record 24 of Set 4 | puurmani
# Processing Record 25 of Set 4 | waipawa
# Processing Record 26 of Set 4 | belaya gora
# Processing Record 27 of Set 4 | dawson creek
# Processing Record 28 of Set 4 | novovarshavka
# Processing Record 29 of Set 4 | alugan
# Processing Record 30 of Set 4 | eydhafushi
# Processing Record 31 of Set 4 | golspie
# Processing Record 32 of Set 4 | bundaberg
# Processing Record 33 of Set 4 | khasan
# Processing Record 34 of Set 4 | ambon
# Processing Record 35 of Set 4 | damghan
# Processing Record 36 of Set 4 | peshkopi
# Processing Record 37 of Set 4 | dhidhdhoo
# Processing Record 38 of Set 4 | surazh
# Processing Record 39 of Set 4 | kaputa
# Processing Record 40 of Set 4 | dikson
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | flinders
# Processing Record 43 of Set 4 | thinadhoo
# Processing Record 44 of Set 4 | hue
# Processing Record 45 of Set 4 | mildura
# Processing Record 46 of Set 4 | nagornskiy
# Processing Record 47 of Set 4 | bredasdorp
# Processing Record 48 of Set 4 | blagoyevo
# Processing Record 49 of Set 4 | xichang
# Processing Record 50 of Set 4 | shchelyayur
# City not found. Skipping...
# Processing Record 1 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 5 | garowe
# Processing Record 3 of Set 5 | zhigansk
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | wadhwan
# City not found. Skipping...
# Processing Record 6 of Set 5 | raga
# Processing Record 7 of Set 5 | krikellos
# Processing Record 8 of Set 5 | ukiah
# Processing Record 9 of Set 5 | belmonte
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | sur
# Processing Record 12 of Set 5 | belokurikha
# Processing Record 13 of Set 5 | batticaloa
# Processing Record 14 of Set 5 | phalodi
# Processing Record 15 of Set 5 | ambilobe
# Processing Record 16 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 17 of Set 5 | marawi
# Processing Record 18 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 19 of Set 5 | tepetzintla
# Processing Record 20 of Set 5 | richards bay
# Processing Record 21 of Set 5 | bar bigha
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | girvan
# Processing Record 24 of Set 5 | nuuk
# Processing Record 25 of Set 5 | northam
# Processing Record 26 of Set 5 | kanye
# Processing Record 27 of Set 5 | koboko
# Processing Record 28 of Set 5 | leshukonskoye
# Processing Record 29 of Set 5 | nikolayevka
# Processing Record 30 of Set 5 | walvis bay
# Processing Record 31 of Set 5 | alofi
# Processing Record 32 of Set 5 | kavieng
# Processing Record 33 of Set 5 | kaitangata
# Processing Record 34 of Set 5 | mahibadhoo
# Processing Record 35 of Set 5 | ribeira grande
# Processing Record 36 of Set 5 | ulaangom
# Processing Record 37 of Set 5 | tonekabon
# Processing Record 38 of Set 5 | tasiilaq
# Processing Record 39 of Set 5 | guasdualito
# Processing Record 40 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 5 | faya
# Processing Record 42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 5 | mahanoro
# Processing Record 44 of Set 5 | riyadh
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | popondetta
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | abu samrah
# Processing Record 49 of Set 5 | fairbanks
# Processing Record 50 of Set 5 | maniitsoq
# Processing Record 1 of Set 6 | quixeramobim
# Processing Record 2 of Set 6 | constitucion
# Processing Record 3 of Set 6 | pisco
# Processing Record 4 of Set 6 | sorland
# Processing Record 5 of Set 6 | mega
# Processing Record 6 of Set 6 | kamenka
# Processing Record 7 of Set 6 | sulangan
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | bandarbeyla
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 6 | kayerkan
# Processing Record 13 of Set 6 | beziers
# Processing Record 14 of Set 6 | komsomolskiy
# Processing Record 15 of Set 6 | ler
# Processing Record 16 of Set 6 | lata
# Processing Record 17 of Set 6 | rorvik
# Processing Record 18 of Set 6 | colares
# Processing Record 19 of Set 6 | kasongo-lunda
# Processing Record 20 of Set 6 | vardo
# Processing Record 21 of Set 6 | wuwei
# Processing Record 22 of Set 6 | airai
# Processing Record 23 of Set 6 | clyde river
# Processing Record 24 of Set 6 | te anau
# Processing Record 25 of Set 6 | ampanihy
# Processing Record 26 of Set 6 | tezu
# Processing Record 27 of Set 6 | mecca
# Processing Record 28 of Set 6 | pontianak
# Processing Record 29 of Set 6 | tucumcari
# Processing Record 30 of Set 6 | ketchikan
# Processing Record 31 of Set 6 | les cayes
# Processing Record 32 of Set 6 | itaporanga
# Processing Record 33 of Set 6 | sukumo
# Processing Record 34 of Set 6 | marfino
# Processing Record 35 of Set 6 | itatiba
# Processing Record 36 of Set 6 | torbay
# Processing Record 37 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 6 | muros
# Processing Record 39 of Set 6 | olafsvik
# Processing Record 40 of Set 6 | uusikaupunki
# Processing Record 41 of Set 6 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 6 | ulagan
# Processing Record 43 of Set 6 | linhares
# Processing Record 44 of Set 6 | mae ramat
# Processing Record 45 of Set 6 | mahebourg
# Processing Record 46 of Set 6 | warri
# Processing Record 47 of Set 6 | carnarvon
# Processing Record 48 of Set 6 | namibe
# Processing Record 49 of Set 6 | hamilton
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | san andres
# Processing Record 2 of Set 7 | paslek
# Processing Record 3 of Set 7 | lakatoro
# Processing Record 4 of Set 7 | jamestown
# Processing Record 5 of Set 7 | paracuru
# Processing Record 6 of Set 7 | salalah
# Processing Record 7 of Set 7 | akonolinga
# Processing Record 8 of Set 7 | morondava
# Processing Record 9 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 10 of Set 7 | plettenberg bay
# Processing Record 11 of Set 7 | nyurba
# Processing Record 12 of Set 7 | lagos
# Processing Record 13 of Set 7 | wylie
# Processing Record 14 of Set 7 | labuhan
# Processing Record 15 of Set 7 | bangolo
# Processing Record 16 of Set 7 | newburn
# Processing Record 17 of Set 7 | andilamena
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | ballina
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | pietarsaari
# Processing Record 22 of Set 7 | tiznit
# Processing Record 23 of Set 7 | orthez
# Processing Record 24 of Set 7 | porto walter
# Processing Record 25 of Set 7 | bud
# Processing Record 26 of Set 7 | chokurdakh
# Processing Record 27 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 28 of Set 7 | chongwe
# Processing Record 29 of Set 7 | warrnambool
# Processing Record 30 of Set 7 | puro
# Processing Record 31 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 7 | pangai
# Processing Record 33 of Set 7 | coquimbo
# Processing Record 34 of Set 7 | yoichi
# Processing Record 35 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 7 | codrington
# Processing Record 37 of Set 7 | anadyr
# Processing Record 38 of Set 7 | passo de camaragibe
# Processing Record 39 of Set 7 | totness
# Processing Record 40 of Set 7 | lodwar
# Processing Record 41 of Set 7 | wloszczowa
# Processing Record 42 of Set 7 | tamandare
# Processing Record 43 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 7 | basco
# Processing Record 45 of Set 7 | mendi
# Processing Record 46 of Set 7 | mabaruma
# Processing Record 47 of Set 7 | halifax
# Processing Record 48 of Set 7 | biak
# Processing Record 49 of Set 7 | anchorage
# Processing Record 50 of Set 7 | zuwarah
# Processing Record 1 of Set 8 | urussu
# Processing Record 2 of Set 8 | sysert
# Processing Record 3 of Set 8 | bethel
# Processing Record 4 of Set 8 | bilma
# Processing Record 5 of Set 8 | okha
# Processing Record 6 of Set 8 | yeppoon
# Processing Record 7 of Set 8 | iskateley
# Processing Record 8 of Set 8 | coueron
# Processing Record 9 of Set 8 | jalu
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 8 | valleyview
# Processing Record 12 of Set 8 | cidreira
# Processing Record 13 of Set 8 | ayolas
# Processing Record 14 of Set 8 | maragogi
# Processing Record 15 of Set 8 | lagoa
# Processing Record 16 of Set 8 | anloga
# Processing Record 17 of Set 8 | comodoro rivadavia
# Processing Record 18 of Set 8 | muswellbrook
# Processing Record 19 of Set 8 | ponta do sol
# Processing Record 20 of Set 8 | hervey bay
# Processing Record 21 of Set 8 | ilulissat
# Processing Record 22 of Set 8 | la paz
# Processing Record 23 of Set 8 | bilibino
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | neiafu
# Processing Record 27 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 28 of Set 8 | henties bay
# Processing Record 29 of Set 8 | maicao
# Processing Record 30 of Set 8 | san joaquin
# Processing Record 31 of Set 8 | slupsk
# Processing Record 32 of Set 8 | mushie
# Processing Record 33 of Set 8 | turukhansk
# Processing Record 34 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 8 | udachnyy
# Processing Record 36 of Set 8 | vanimo
# Processing Record 37 of Set 8 | mount isa
# Processing Record 38 of Set 8 | narsaq
# Processing Record 39 of Set 8 | gayeri
# Processing Record 40 of Set 8 | jaboatao
# Processing Record 41 of Set 8 | coihaique
# Processing Record 42 of Set 8 | saint-pierre
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | jardim
# Processing Record 45 of Set 8 | nemea
# Processing Record 46 of Set 8 | umea
# Processing Record 47 of Set 8 | hailin
# Processing Record 48 of Set 8 | oranjestad
# Processing Record 49 of Set 8 | puri
# Processing Record 50 of Set 8 | caconda
# Processing Record 1 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 9 | dingle
# Processing Record 3 of Set 9 | valparaiso
# Processing Record 4 of Set 9 | belawan
# Processing Record 5 of Set 9 | rawson
# Processing Record 6 of Set 9 | kodiak
# Processing Record 7 of Set 9 | ye
# City not found. Skipping...
# Processing Record 8 of Set 9 | puerto madryn
# Processing Record 9 of Set 9 | kushima
# Processing Record 10 of Set 9 | chabahar
# Processing Record 11 of Set 9 | pacific grove
# Processing Record 12 of Set 9 | arlit
# Processing Record 13 of Set 9 | ulaanbaatar
# Processing Record 14 of Set 9 | campbell river
# Processing Record 15 of Set 9 | prince rupert
# Processing Record 16 of Set 9 | upata
# Processing Record 17 of Set 9 | kailua
# Processing Record 18 of Set 9 | marsaxlokk
# Processing Record 19 of Set 9 | kilmez
# City not found. Skipping...
# Processing Record 20 of Set 9 | deniliquin
# Processing Record 21 of Set 9 | ojinaga
# Processing Record 22 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 9 | bad aussee
# Processing Record 24 of Set 9 | loukhi
# Processing Record 25 of Set 9 | whitianga
# Processing Record 26 of Set 9 | jamame
# Processing Record 27 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 9 | verkhnyaya maksakovka
# Processing Record 30 of Set 9 | celestun
# Processing Record 31 of Set 9 | port blair
# Processing Record 32 of Set 9 | aklavik
# Processing Record 33 of Set 9 | novobirilyussy
# Processing Record 34 of Set 9 | cabo san lucas
# Processing Record 35 of Set 9 | maumere
# Processing Record 36 of Set 9 | geraldton
# Processing Record 37 of Set 9 | mana
# Processing Record 38 of Set 9 | kimbe
# Processing Record 39 of Set 9 | kirakira
# Processing Record 40 of Set 9 | ano mera
# Processing Record 41 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 9 | koumac
# Processing Record 43 of Set 9 | nioro
# Processing Record 44 of Set 9 | mandapam
# Processing Record 45 of Set 9 | devils lake
# Processing Record 46 of Set 9 | saint-augustin
# Processing Record 47 of Set 9 | yar-sale
# Processing Record 48 of Set 9 | burnie
# Processing Record 49 of Set 9 | ahipara
# Processing Record 50 of Set 9 | bend
# Processing Record 1 of Set 10 | chicama
# Processing Record 2 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 10 | mastic beach
# Processing Record 4 of Set 10 | aksu
# Processing Record 5 of Set 10 | lethem
# Processing Record 6 of Set 10 | axim
# Processing Record 7 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 10 | alyangula
# Processing Record 9 of Set 10 | savonlinna
# Processing Record 10 of Set 10 | tucuman
# Processing Record 11 of Set 10 | half moon bay
# Processing Record 12 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 10 | tamiahua
# Processing Record 14 of Set 10 | razole
# Processing Record 15 of Set 10 | poum
# Processing Record 16 of Set 10 | san quintin
# Processing Record 17 of Set 10 | kostomuksha
# Processing Record 18 of Set 10 | aswan
# Processing Record 19 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 10 | xunchang
# Processing Record 22 of Set 10 | bam
# Processing Record 23 of Set 10 | san ramon
# Processing Record 24 of Set 10 | skibbereen
# Processing Record 25 of Set 10 | takoradi
# Processing Record 26 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 27 of Set 10 | tomatlan
# Processing Record 28 of Set 10 | padang
# Processing Record 29 of Set 10 | bambanglipuro
# Processing Record 30 of Set 10 | aberystwyth
# Processing Record 31 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 32 of Set 10 | kibala
# Processing Record 33 of Set 10 | vila velha
# Processing Record 34 of Set 10 | severnoye
# Processing Record 35 of Set 10 | carutapera
# Processing Record 36 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 10 | santo domingo
# Processing Record 38 of Set 10 | bathsheba
# Processing Record 39 of Set 10 | tarauaca
# Processing Record 40 of Set 10 | huarmey
# Processing Record 41 of Set 10 | gorom-gorom
# Processing Record 42 of Set 10 | tete
# Processing Record 43 of Set 10 | nha trang
# Processing Record 44 of Set 10 | elizabeth city
# Processing Record 45 of Set 10 | kisanga
# Processing Record 46 of Set 10 | oxapampa
# Processing Record 47 of Set 10 | estacion coahuila
# Processing Record 48 of Set 10 | terra boa
# Processing Record 49 of Set 10 | bairiki
# Processing Record 50 of Set 10 | mayskiy
# Processing Record 1 of Set 11 | xiamen
# Processing Record 2 of Set 11 | beyneu
# Processing Record 3 of Set 11 | mongoumba
# Processing Record 4 of Set 11 | saskylakh
# Processing Record 5 of Set 11 | homer
# Processing Record 6 of Set 11 | nalut
# Processing Record 7 of Set 11 | adrar
# Processing Record 8 of Set 11 | san policarpo
# Processing Record 9 of Set 11 | iberia
# Processing Record 10 of Set 11 | sagua la grande
# Processing Record 11 of Set 11 | victoria falls
# Processing Record 12 of Set 11 | tulum
# Processing Record 13 of Set 11 | gamboma
# Processing Record 14 of Set 11 | pareora
# Processing Record 15 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 16 of Set 11 | lexington park
# Processing Record 17 of Set 11 | lannion
# Processing Record 18 of Set 11 | buin
# Processing Record 19 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 11 | prince george
# Processing Record 21 of Set 11 | puerto escondido
# Processing Record 22 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 11 | tagab
# Processing Record 24 of Set 11 | longyearbyen
# Processing Record 25 of Set 11 | guaymas
# Processing Record 26 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 11 | channel-port aux basques
# Processing Record 28 of Set 11 | hami
# Processing Record 29 of Set 11 | saint-joseph
# Processing Record 30 of Set 11 | igurubi
# Processing Record 31 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 32 of Set 11 | wilmington
# Processing Record 33 of Set 11 | kamina
# Processing Record 34 of Set 11 | mackay
# Processing Record 35 of Set 11 | oistins
# Processing Record 36 of Set 11 | yakima
# Processing Record 37 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 38 of Set 11 | calvia
# Processing Record 39 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 11 | umm lajj
# Processing Record 41 of Set 11 | kharp
# Processing Record 42 of Set 11 | preobrazheniye
# Processing Record 43 of Set 11 | tibiri
# Processing Record 44 of Set 11 | awbari
# Processing Record 45 of Set 11 | varna
# Processing Record 46 of Set 11 | gornyak
# Processing Record 47 of Set 11 | el alto
# Processing Record 48 of Set 11 | abha
# Processing Record 49 of Set 11 | vrede
# Processing Record 50 of Set 11 | doume
# Processing Record 1 of Set 12 | ahuimanu
# Processing Record 2 of Set 12 | liepaja
# Processing Record 3 of Set 12 | abbeville
# Processing Record 4 of Set 12 | chateaudun
# Processing Record 5 of Set 12 | sagar
# Processing Record 6 of Set 12 | oeiras do para
# Processing Record 7 of Set 12 | severnyy
# Processing Record 8 of Set 12 | kapuskasing
# Processing Record 9 of Set 12 | charters towers
# Processing Record 10 of Set 12 | yumaguzino
# Processing Record 11 of Set 12 | saint anthony
# Processing Record 12 of Set 12 | westport
# Processing Record 13 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 14 of Set 12 | miyako
# Processing Record 15 of Set 12 | bereznik
# Processing Record 16 of Set 12 | kalemie
# Processing Record 17 of Set 12 | pimentel
# Processing Record 18 of Set 12 | kyaukse
# Processing Record 19 of Set 12 | deputatskiy
# Processing Record 20 of Set 12 | mangai
# Processing Record 21 of Set 12 | zhangye
# Processing Record 22 of Set 12 | mount pleasant
# Processing Record 23 of Set 12 | mikkeli
# Processing Record 24 of Set 12 | uige
# Processing Record 25 of Set 12 | taksimo
# Processing Record 26 of Set 12 | iwanai
# Processing Record 27 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 12 | berlevag
# Processing Record 29 of Set 12 | inhambane
# Processing Record 30 of Set 12 | iquique
# Processing Record 31 of Set 12 | vila franca do campo
# Processing Record 32 of Set 12 | pirapora do bom jesus
# Processing Record 33 of Set 12 | wagar
# Processing Record 34 of Set 12 | nome
# Processing Record 35 of Set 12 | ati
# Processing Record 36 of Set 12 | taltal
# Processing Record 37 of Set 12 | lompoc
# Processing Record 38 of Set 12 | monduli
# Processing Record 39 of Set 12 | havoysund
# Processing Record 40 of Set 12 | san clemente
# Processing Record 41 of Set 12 | krompachy
# Processing Record 42 of Set 12 | soledade
# Processing Record 43 of Set 12 | groton
# Processing Record 44 of Set 12 | muscatine
# Processing Record 45 of Set 12 | inongo
# Processing Record 46 of Set 12 | baghdad
# Processing Record 47 of Set 12 | sorong
# Processing Record 48 of Set 12 | broome
# Processing Record 49 of Set 12 | barsovo
# Processing Record 50 of Set 12 | acari
# Processing Record 1 of Set 13 | teguldet
# Processing Record 2 of Set 13 | arrecife
# Processing Record 3 of Set 13 | verkhovazhye
# Processing Record 4 of Set 13 | lasa
# Processing Record 5 of Set 13 | rabo de peixe
# Processing Record 6 of Set 13 | muli
# Processing Record 7 of Set 13 | maple creek
# Processing Record 8 of Set 13 | chalchihuites
# Processing Record 9 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 10 of Set 13 | promissao
# Processing Record 11 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 13 | saryozek
# Processing Record 13 of Set 13 | grand-bourg
# Processing Record 14 of Set 13 | nautla
# Processing Record 15 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 13 | fenoarivo atsinanana
# Processing Record 17 of Set 13 | karratha
# Processing Record 18 of Set 13 | strezhevoy
# Processing Record 19 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 13 | santa barbara
# Processing Record 21 of Set 13 | sovetskaya gavan
# Processing Record 22 of Set 13 | sola
# Processing Record 23 of Set 13 | morro bay
# Processing Record 24 of Set 13 | vaslui
# Processing Record 25 of Set 13 | margate
# Processing Record 26 of Set 13 | mareeba
# Processing Record 27 of Set 13 | bom jesus
# Processing Record 28 of Set 13 | nyrob
# Processing Record 29 of Set 13 | talcahuano
# Processing Record 30 of Set 13 | jega
# Processing Record 31 of Set 13 | soller
# Processing Record 32 of Set 13 | perbaungan
# Processing Record 33 of Set 13 | tuatapere
# Processing Record 34 of Set 13 | hrebinka
# Processing Record 35 of Set 13 | taoudenni
# Processing Record 36 of Set 13 | bubaque
# Processing Record 37 of Set 13 | bontang
# Processing Record 38 of Set 13 | fukue
# Processing Record 39 of Set 13 | boueni
# Processing Record 40 of Set 13 | alta floresta
# Processing Record 41 of Set 13 | junagarh
# Processing Record 42 of Set 13 | acapulco
# Processing Record 43 of Set 13 | whitehorse
# Processing Record 44 of Set 13 | mitha tiwana
# Processing Record 45 of Set 13 | chapais
# Processing Record 46 of Set 13 | dunedin
# Processing Record 47 of Set 13 | nemuro
# Processing Record 48 of Set 13 | tshela
# Processing Record 49 of Set 13 | surgut
# Processing Record 50 of Set 13 | pecos
# Processing Record 1 of Set 14 | naze
# Processing Record 2 of Set 14 | bardiyah
# Processing Record 3 of Set 14 | mehamn
# Processing Record 4 of Set 14 | sambava
# Processing Record 5 of Set 14 | pedernales
# Processing Record 6 of Set 14 | eureka
# Processing Record 7 of Set 14 | catia la mar
# Processing Record 8 of Set 14 | san jose
# Processing Record 9 of Set 14 | omboue
# Processing Record 10 of Set 14 | talant
# Processing Record 11 of Set 14 | jiuquan
# Processing Record 12 of Set 14 | katiola
# Processing Record 13 of Set 14 | thatcham
# Processing Record 14 of Set 14 | afgoye
# City not found. Skipping...
# Processing Record 15 of Set 14 | port macquarie
# Processing Record 16 of Set 14 | biloela
# Processing Record 17 of Set 14 | itaituba
# Processing Record 18 of Set 14 | namatanai
# Processing Record 19 of Set 14 | mayo
# Processing Record 20 of Set 14 | fernie
# Processing Record 21 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 14 | puerto colombia
# Processing Record 23 of Set 14 | chake chake
# Processing Record 24 of Set 14 | kargala
# Processing Record 25 of Set 14 | dhekiajuli
# Processing Record 26 of Set 14 | malakal
# Processing Record 27 of Set 14 | artigas
# Processing Record 28 of Set 14 | solok
# Processing Record 29 of Set 14 | general pico
# Processing Record 30 of Set 14 | lodja
# Processing Record 31 of Set 14 | goure
# Processing Record 32 of Set 14 | portland
# Processing Record 33 of Set 14 | svay rieng
# Processing Record 34 of Set 14 | yumen
# Processing Record 35 of Set 14 | qasigiannguit
# Processing Record 36 of Set 14 | puerto carreno
# Processing Record 37 of Set 14 | balakhninskiy
# Processing Record 38 of Set 14 | shihezi
# Processing Record 39 of Set 14 | linqing
# Processing Record 40 of Set 14 | havre-saint-pierre
# Processing Record 41 of Set 14 | baherden
# Processing Record 42 of Set 14 | kirovskiy
# Processing Record 43 of Set 14 | visby
# Processing Record 44 of Set 14 | gobabis
# Processing Record 45 of Set 14 | shakawe
# Processing Record 46 of Set 14 | spring valley
# Processing Record 47 of Set 14 | diamantina
# Processing Record 48 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 14 | rocha
# Processing Record 50 of Set 14 | sept-iles
# Processing Record 1 of Set 15 | rimouski
# Processing Record 2 of Set 15 | shimoda
# Processing Record 3 of Set 15 | coihueco
# Processing Record 4 of Set 15 | veenendaal
# Processing Record 5 of Set 15 | verkhoshizhemye
# Processing Record 6 of Set 15 | pithoro
# Processing Record 7 of Set 15 | mazamari
# Processing Record 8 of Set 15 | atherton
# Processing Record 9 of Set 15 | ljungby
# Processing Record 10 of Set 15 | veraval
# Processing Record 11 of Set 15 | isangel
# Processing Record 12 of Set 15 | leh
# Processing Record 13 of Set 15 | bermeo
# Processing Record 14 of Set 15 | mogadishu
# Processing Record 15 of Set 15 | santiago del estero
# Processing Record 16 of Set 15 | maldonado
# Processing Record 17 of Set 15 | sistranda
# Processing Record 18 of Set 15 | pingliang
# Processing Record 19 of Set 15 | kerema
# Processing Record 20 of Set 15 | santa fe
# Processing Record 21 of Set 15 | kuching
# Processing Record 22 of Set 15 | loandjili
# Processing Record 23 of Set 15 | corinto
# Processing Record 24 of Set 15 | yingzhong
# City not found. Skipping...
# Processing Record 25 of Set 15 | lashma
# Processing Record 26 of Set 15 | marzuq
# Processing Record 27 of Set 15 | u thong
# Processing Record 28 of Set 15 | qingdao
# Processing Record 29 of Set 15 | kenai
# Processing Record 30 of Set 15 | las piedras
# Processing Record 31 of Set 15 | singida
# Processing Record 32 of Set 15 | alice springs
# Processing Record 33 of Set 15 | sao paulo de olivenca
# Processing Record 34 of Set 15 | rapid valley
# Processing Record 35 of Set 15 | kudahuvadhoo
# Processing Record 36 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 15 | hovd
# Processing Record 38 of Set 15 | wawa
# Processing Record 39 of Set 15 | tahta
# Processing Record 40 of Set 15 | quatre cocos
# Processing Record 41 of Set 15 | bondo
# Processing Record 42 of Set 15 | price
# Processing Record 43 of Set 15 | mariental
# Processing Record 44 of Set 15 | samarai
# Processing Record 45 of Set 15 | ipixuna
# Processing Record 46 of Set 15 | tsimlyansk
# Processing Record 47 of Set 15 | susehri
# Processing Record 48 of Set 15 | villa bruzual
# Processing Record 49 of Set 15 | meulaboh
# Processing Record 50 of Set 15 | miles city
# Processing Record 1 of Set 16 | ilhabela
# Processing Record 2 of Set 16 | tena
# Processing Record 3 of Set 16 | kavaratti
# Processing Record 4 of Set 16 | shenkursk
# Processing Record 5 of Set 16 | yelizovo
# Processing Record 6 of Set 16 | ocos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaires to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng Current Description  Max Temp  \
# 0  Sao Joao Da Barra -21.6403  -41.0511           clear sky     82.40
# 1         Champerico  14.3000  -91.9167    scattered clouds     91.40
# 2             Albany  42.6001  -73.9662     overcast clouds     17.01
# 3             Hobart -42.8794  147.3294       broken clouds     69.01
# 4             Aykhal  66.0000  111.5000     overcast clouds    -41.69
# 5            Mataura -46.1927  168.8643       broken clouds     71.24
# 6        Canyon Lake  29.8752  -98.2625           clear sky     66.99
# 7             Lokoja   7.8024    6.7430    scattered clouds     81.82
# 8          Road Town  18.4167  -64.6167    scattered clouds     78.80
# 9         Nikolskoye  59.7035   30.7861                snow     26.60
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        65           0       23.02      BR
# 1        52          40       11.50      GT
# 2        52         100        2.53      US
# 3        68          75        6.91      AU
# 4        78         100        9.80      RU
# 5        45          56        2.57      NZ
# 6        33           0       11.01      US
# 7        22          38        3.09      NG
# 8        78          40       10.36      VG
# 9        86          90        6.71      RU

# %%
# reorder the columnes
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Sao Joao Da Barra      BR -21.6403  -41.0511     82.40        65
# 1         Champerico      GT  14.3000  -91.9167     91.40        52
# 2             Albany      US  42.6001  -73.9662     17.01        52
# 3             Hobart      AU -42.8794  147.3294     69.01        68
# 4             Aykhal      RU  66.0000  111.5000    -41.69        78
# 5            Mataura      NZ -46.1927  168.8643     71.24        45
# 6        Canyon Lake      US  29.8752  -98.2625     66.99        33
# 7             Lokoja      NG   7.8024    6.7430     81.82        22
# 8          Road Town      VG  18.4167  -64.6167     78.80        78
# 9         Nikolskoye      RU  59.7035   30.7861     26.60        86
#
#    Cloudiness  Wind Speed Current Description
# 0           0       23.02           clear sky
# 1          40       11.50    scattered clouds
# 2         100        2.53     overcast clouds
# 3          75        6.91       broken clouds
# 4         100        9.80     overcast clouds
# 5          56        2.57       broken clouds
# 6           0       11.01           clear sky
# 7          38        3.09    scattered clouds
# 8          40       10.36    scattered clouds
# 9          90        6.71                snow

# %%
# Create the output files (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
